# %% [markdown]
# <a href="https://colab.research.google.com/github/HarrisKucukalic/CSS2_Group_3/blob/main/Angie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Connect to Google Drive, Import Libraries and Datasets

# %% [markdown]
# ## Connect to drive and check Directory

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/Shareddrives/CSS2 - Research /Research Code
# Out:
# /content/gdrive/Shareddrives/CSS2 - Research /Research Code

# %%
# !ls
# Out:
# Angie.ipynb  Harris.ipynb  Samuel.ipynb   Timothy.ipynb
# desktop.ini  Isaac.ipynb   Test_data.csv  Train_data.csv

# %% [markdown]
# ## Import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_theme(rc={"figure.dpi":120, 'savefig.dpi':120})

# sklearn
import sklearn as sk
from sklearn import *
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import *

# #GaussianNB
# from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# ## Intrusion Detection Data

# %%
intrusion_data = pd.read_csv('Train_data.csv')
intrusion_data
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp  ftp_data    SF        491          0     0
# 1             0           udp     other    SF        146          0     0
# 2             0           tcp   private    S0          0          0     0
# 3             0           tcp      http    SF        232       8153     0
# 4             0           tcp      http    SF        199        420     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 25187         0           tcp      exec  RSTO          0          0     0
# 25188         0           tcp  ftp_data    SF        334          0     0
# 25189         0           tcp   private   REJ          0          0     0
# 25190         0           tcp      nnsp    S0          0          0     0
# 25191         0           tcp    finger    S0          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0                   0       0    0  ...                  25
# 1                   0       0    0  ...                   1
# 2                   0       0    0  ...                  26
# 3                   0       0    0  ...                 255
# 4                   0       0    0  ...                 255
# ...               ...     ...  ...  ...                 ...
# 25187               0       0    0  ...                   7
# 25188               0       0    0  ...                  39
# 25189               0       0    0  ...                  13
# 25190               0       0    0  ...                  20
# 25191               0       0    0  ...                  49
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                        0.17                    0.03
# 1                        0.00                    0.60
# 2                        0.10                    0.05
# 3                        1.00                    0.00
# 4                        1.00                    0.00
# ...                       ...                     ...
# 25187                    0.03                    0.06
# 25188                    1.00                    0.00
# 25189                    0.05                    0.07
# 25190                    0.08                    0.06
# 25191                    0.19                    0.03
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                             0.17                         0.00
# 1                             0.88                         0.00
# 2                             0.00                         0.00
# 3                             0.03                         0.04
# 4                             0.00                         0.00
# ...                            ...                          ...
# 25187                         0.00                         0.00
# 25188                         1.00                         0.18
# 25189                         0.00                         0.00
# 25190                         0.00                         0.00
# 25191                         0.01                         0.00
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                      0.00                      0.00                  0.05
# 1                      0.00                      0.00                  0.00
# 2                      1.00                      1.00                  0.00
# 3                      0.03                      0.01                  0.00
# 4                      0.00                      0.00                  0.00
# ...                     ...                       ...                   ...
# 25187                  0.00                      0.00                  1.00
# 25188                  0.00                      0.00                  0.00
# 25189                  0.00                      0.00                  1.00
# 25190                  1.00                      1.00                  0.00
# 25191                  1.00                      1.00                  0.00
#
#        dst_host_srv_rerror_rate    class
# 0                          0.00   normal
# 1                          0.00   normal
# 2                          0.00  anomaly
# 3                          0.01   normal
# 4                          0.00   normal
# ...                         ...      ...
# 25187                      1.00  anomaly
# 25188                      0.00  anomaly
# 25189                      1.00  anomaly
# 25190                      0.00  anomaly
# 25191                      0.00  anomaly
#
# [25192 rows x 42 columns]

# %%
intrusion_data['class'].value_counts()
# Out:
# normal     13449
# anomaly    11743
# Name: class, dtype: int64

# %%
value_counts = intrusion_data['class'].value_counts()
total_values = len(intrusion_data['class'].dropna())
percentages = (value_counts / total_values) * 100
print(percentages)
# Out:
# normal     53.385996
# anomaly    46.614004
# Name: class, dtype: float64

# %% [markdown]
# # Preprocessing

# %%
total_rows = len(intrusion_data)

missing_values = intrusion_data.isna().sum()

percentage_missing = (missing_values / total_rows) * 100
percentage_missing = percentage_missing.round(2)
print(percentage_missing)
# Out:
# duration                       0.0
# protocol_type                  0.0
# service                        0.0
# flag                           0.0
# src_bytes                      0.0
# dst_bytes                      0.0
# land                           0.0
# wrong_fragment                 0.0
# urgent                         0.0
# hot                            0.0
# num_failed_logins              0.0
# logged_in                      0.0
# num_compromised                0.0
# root_shell                     0.0
# su_attempted                   0.0
# num_root                       0.0
# num_file_creations             0.0
# num_shells                     0.0
# num_access_files               0.0
# num_outbound_cmds              0.0
# is_host_login                  0.0
# is_guest_login                 0.0
# count                          0.0
# srv_count                      0.0
# serror_rate                    0.0
# srv_serror_rate                0.0
# rerror_rate                    0.0
# srv_rerror_rate                0.0
# same_srv_rate                  0.0
# diff_srv_rate                  0.0
# srv_diff_host_rate             0.0
# dst_host_count                 0.0
# dst_host_srv_count             0.0
# dst_host_same_srv_rate         0.0
# dst_host_diff_srv_rate         0.0
# dst_host_same_src_port_rate    0.0
# dst_host_srv_diff_host_rate    0.0
# dst_host_serror_rate           0.0
# dst_host_srv_serror_rate       0.0
# dst_host_rerror_rate           0.0
# dst_host_srv_rerror_rate       0.0
# class                          0.0
# dtype: float64

# %% [markdown]
# #Testing Data

# %%
for column in intrusion_data.columns:
    print(f"Counts for {column}:")
    print(intrusion_data[column].value_counts())
    print("------------")
# Out:
# Counts for duration:
# 0        23168
# 1          374
# 2          165
# 3          102
# 4           75
#          ...
# 17025        1
# 12892        1
# 584          1
# 10774        1
# 322          1
# Name: duration, Length: 758, dtype: int64
# ------------
# Counts for protocol_type:
# tcp     20526
# udp      3011
# icmp     1655
# Name: protocol_type, dtype: int64
# ------------
# Counts for service:
# http         8003
# private      4351
# domain_u     1820
# smtp         1449
# ftp_data     1396
#              ...
# urh_i           4
# red_i           3
# pm_dump         3
# tim_i           2
# http_8001       1
# Name: service, Length: 66, dtype: int64
# ------------
# Counts for flag:
# SF        14973
# S0         7009
# REJ        2216
# RSTR        497
# RSTO        304
# S1           88
# SH           43
# RSTOS0       21
# S2           21
# S3           15
# OTH           5
# Name: flag, dtype: int64
# ------------
# Counts for src_bytes:
# 0        9866
# 8         738
# 1         480
# 44        467
# 45        416
#          ...
# 3724        1
# 44788       1
# 1205        1
# 827         1
# 2896        1
# Name: src_bytes, Length: 1665, dtype: int64
# ------------
# Counts for dst_bytes:
# 0        13574
# 105        309
# 8314       175
# 44         115
# 42         105
#          ...
# 752          1
# 23681        1
# 6393         1
# 1044         1
# 2257         1
# Name: dst_bytes, Length: 3922, dtype: int64
# ------------
# Counts for land:
# 0    25190
# 1        2
# Name: land, dtype: int64
# ------------
# Counts for wrong_fragment:
# 0    24968
# 3      187
# 1       37
# Name: wrong_fragment, dtype: int64
# ------------
# Counts for urgent:
# 0    25191
# 1        1
# Name: urgent, dtype: int64
# ------------
# Counts for hot:
# 0     24672
# 2       200
# 1        78
# 30       55
# 28       52
# 4        37
# 6        26
# 5        17
# 22       13
# 24        9
# 19        8
# 3         7
# 18        6
# 14        3
# 7         2
# 15        1
# 25        1
# 77        1
# 17        1
# 11        1
# 20        1
# 12        1
# Name: hot, dtype: int64
# ------------
# Counts for num_failed_logins:
# 0    25169
# 1       19
# 2        2
# 3        1
# 4        1
# Name: num_failed_logins, dtype: int64
# ------------
# Counts for logged_in:
# 0    15247
# 1     9945
# Name: logged_in, dtype: int64
# ------------
# Counts for num_compromised:
# 0      24920
# 1        194
# 2         21
# 4         13
# 6          8
# 3          7
# 5          5
# 7          2
# 151        2
# 12         2
# 83         1
# 558        1
# 789        1
# 520        1
# 884        1
# 217        1
# 371        1
# 193        1
# 31         1
# 13         1
# 157        1
# 9          1
# 110        1
# 462        1
# 107        1
# 38         1
# 19         1
# 457        1
# Name: num_compromised, dtype: int64
# ------------
# Counts for root_shell:
# 0    25153
# 1       39
# Name: root_shell, dtype: int64
# ------------
# Counts for su_attempted:
# 0    25171
# 2       13
# 1        8
# Name: su_attempted, dtype: int64
# ------------
# Counts for num_root:
# 0      25058
# 1         47
# 9         24
# 6         23
# 2         10
# 5          6
# 4          2
# 3          2
# 14         1
# 100        1
# 975        1
# 10         1
# 572        1
# 867        1
# 191        1
# 91         1
# 247        1
# 146        1
# 417        1
# 629        1
# 7          1
# 179        1
# 54         1
# 38         1
# 151        1
# 121        1
# 512        1
# 508        1
# Name: num_root, dtype: int64
# ------------
# Counts for num_file_creations:
# 0     25126
# 1        37
# 2         7
# 4         3
# 8         2
# 18        2
# 5         2
# 21        1
# 11        1
# 20        1
# 3         1
# 40        1
# 17        1
# 6         1
# 14        1
# 19        1
# 29        1
# 13        1
# 15        1
# 38        1
# Name: num_file_creations, dtype: int64
# ------------
# Counts for num_shells:
# 0    25183
# 1        9
# Name: num_shells, dtype: int64
# ------------
# Counts for num_access_files:
# 0    25113
# 1       65
# 2        8
# 3        2
# 5        2
# 4        1
# 8        1
# Name: num_access_files, dtype: int64
# ------------
# Counts for num_outbound_cmds:
# 0    25192
# Name: num_outbound_cmds, dtype: int64
# ------------
# Counts for is_host_login:
# 0    25192
# Name: is_host_login, dtype: int64
# ------------
# Counts for is_guest_login:
# 0    24962
# 1      230
# Name: is_guest_login, dtype: int64
# ------------
# Counts for count:
# 1      5519
# 2      1934
# 3       769
# 4       696
# 5       597
#        ...
# 410       1
# 318       1
# 353       1
# 481       1
# 328       1
# Name: count, Length: 466, dtype: int64
# ------------
# Counts for srv_count:
# 1      5080
# 2      2538
# 3      1223
# 4      1086
# 5       913
#        ...
# 481       1
# 278       1
# 338       1
# 351       1
# 408       1
# Name: srv_count, Length: 414, dtype: int64
# ------------
# Counts for serror_rate:
# 0.00    17329
# 1.00     6941
# 0.50      122
# 0.07       53
# 0.06       50
#         ...
# 0.26        1
# 0.55        1
# 0.91        1
# 0.59        1
# 0.74        1
# Name: serror_rate, Length: 70, dtype: int64
# ------------
# Counts for srv_serror_rate:
# 0.00    17708
# 1.00     7003
# 0.50       94
# 0.33       51
# 0.25       42
# 0.20       32
# 0.05       26
# 0.17       22
# 0.03       20
# 0.04       20
# 0.07       16
# 0.02       13
# 0.67       13
# 0.09       10
# 0.10       10
# 0.08       10
# 0.06       10
# 0.12       10
# 0.95        9
# 0.14        9
# 0.11        8
# 0.40        5
# 0.90        4
# 0.22        4
# 0.80        3
# 0.91        3
# 0.89        3
# 0.92        3
# 0.29        2
# 0.76        2
# 0.18        2
# 0.45        1
# 0.13        1
# 0.65        1
# 0.75        1
# 0.39        1
# 0.59        1
# 0.46        1
# 0.88        1
# 0.83        1
# 0.26        1
# 0.41        1
# 0.74        1
# 0.01        1
# 0.86        1
# 0.94        1
# 0.93        1
# 0.57        1
# 0.60        1
# 0.34        1
# 0.36        1
# 0.55        1
# 0.53        1
# 0.78        1
# 0.43        1
# 0.15        1
# Name: srv_serror_rate, dtype: int64
# ------------
# Counts for rerror_rate:
# 0.00    21985
# 1.00     2552
# 0.90       43
# 0.89       39
# 0.91       38
#         ...
# 0.09        1
# 0.44        1
# 0.21        1
# 0.32        1
# 0.57        1
# Name: rerror_rate, Length: 72, dtype: int64
# ------------
# Counts for srv_rerror_rate:
# 0.00    21959
# 1.00     2937
# 0.50       56
# 0.33       32
# 0.25       26
# 0.17       17
# 0.20       16
# 0.04       14
# 0.08       11
# 0.67       11
# 0.14       10
# 0.06       10
# 0.02        9
# 0.05        8
# 0.03        8
# 0.10        8
# 0.07        7
# 0.12        5
# 0.75        5
# 0.62        4
# 0.83        3
# 0.40        3
# 0.29        3
# 0.80        3
# 0.11        3
# 0.43        2
# 0.60        2
# 0.81        2
# 0.64        2
# 0.09        2
# 0.79        2
# 0.71        2
# 0.56        1
# 0.84        1
# 0.74        1
# 0.38        1
# 0.85        1
# 0.15        1
# 0.69        1
# 0.73        1
# 0.76        1
# 0.57        1
# Name: srv_rerror_rate, dtype: int64
# ------------
# Counts for same_srv_rate:
# 1.00    15357
# 0.01      827
# 0.02      710
# 0.06      681
# 0.03      678
#         ...
# 0.78        1
# 0.70        1
# 0.61        1
# 0.82        1
# 0.81        1
# Name: same_srv_rate, Length: 97, dtype: int64
# ------------
# Counts for diff_srv_rate:
# 0.00    15245
# 0.06     3861
# 0.07     1947
# 0.05     1350
# 1.00      663
#         ...
# 0.76        1
# 0.59        1
# 0.77        1
# 0.56        1
# 0.70        1
# Name: diff_srv_rate, Length: 79, dtype: int64
# ------------
# Counts for srv_diff_host_rate:
# 0.00    19517
# 1.00     1559
# 0.01      586
# 0.67      210
# 0.50      193
# 0.12      170
# 0.33      167
# 0.25      164
# 0.02      153
# 0.11      143
# 0.10      138
# 0.29      129
# 0.18      129
# 0.17      128
# 0.08      124
# 0.40      123
# 0.20      122
# 0.14      121
# 0.06      118
# 0.09      112
# 0.07      111
# 0.15      111
# 0.22      111
# 0.13       81
# 0.05       59
# 0.75       58
# 0.19       57
# 0.21       47
# 0.16       46
# 0.23       43
# 0.27       42
# 0.60       41
# 0.03       40
# 0.04       39
# 0.43       34
# 0.30       29
# 0.38       28
# 0.36       21
# 0.80       14
# 0.31       11
# 0.24       11
# 0.44        7
# 0.57        7
# 0.28        6
# 0.42        5
# 0.26        4
# 0.56        4
# 0.45        3
# 0.62        3
# 0.71        3
# 0.32        2
# 0.35        2
# 0.37        2
# 0.83        1
# 0.55        1
# 0.88        1
# 0.47        1
# Name: srv_diff_host_rate, dtype: int64
# ------------
# Counts for dst_host_count:
# 255    14850
# 1        601
# 2        554
# 3        251
# 4        241
#        ...
# 219       11
# 229       10
# 206        9
# 233        8
# 0          1
# Name: dst_host_count, Length: 256, dtype: int64
# ------------
# Counts for dst_host_srv_count:
# 255    7148
# 1      1658
# 2      1041
# 3       556
# 4       516
#        ...
# 188      11
# 204      10
# 220       9
# 221       7
# 0         1
# Name: dst_host_srv_count, Length: 256, dtype: int64
# ------------
# Counts for dst_host_same_srv_rate:
# 1.00    9758
# 0.01    1541
# 0.00    1379
# 0.02    1325
# 0.07    1122
#         ...
# 0.51      33
# 0.37      33
# 0.68      32
# 0.42      30
# 0.66      26
# Name: dst_host_same_srv_rate, Length: 101, dtype: int64
# ------------
# Counts for dst_host_diff_srv_rate:
# 0.00    9343
# 0.07    3448
# 0.06    1917
# 0.01    1881
# 0.05    1436
#         ...
# 0.41       6
# 0.98       6
# 0.88       5
# 0.90       5
# 0.93       3
# Name: dst_host_diff_srv_rate, Length: 101, dtype: int64
# ------------
# Counts for dst_host_same_src_port_rate:
# 0.00    12673
# 0.01     3557
# 1.00     2052
# 0.02     1115
# 0.03      624
#         ...
# 0.63       11
# 0.65       11
# 0.72       10
# 0.66        9
# 0.81        9
# Name: dst_host_same_src_port_rate, Length: 101, dtype: int64
# ------------
# Counts for dst_host_srv_diff_host_rate:
# 0.00    17387
# 0.02     1612
# 0.01     1468
# 0.03      950
# 0.04      870
#         ...
# 0.46        1
# 0.36        1
# 0.42        1
# 0.39        1
# 0.86        1
# Name: dst_host_srv_diff_host_rate, Length: 63, dtype: int64
# ------------
# Counts for dst_host_serror_rate:
# 0.00    16221
# 1.00     6739
# 0.01      680
# 0.02      237
# 0.03      149
#         ...
# 0.28        1
# 0.61        1
# 0.32        1
# 0.83        1
# 0.54        1
# Name: dst_host_serror_rate, Length: 100, dtype: int64
# ------------
# Counts for dst_host_srv_serror_rate:
# 0.00    17005
# 1.00     6862
# 0.01      758
# 0.02      136
# 0.03       32
#         ...
# 0.77        1
# 0.87        1
# 0.84        1
# 0.82        1
# 0.24        1
# Name: dst_host_srv_serror_rate, Length: 88, dtype: int64
# ------------
# Counts for dst_host_rerror_rate:
# 0.00    20688
# 1.00     2069
# 0.01      359
# 0.02      232
# 0.03      110
#         ...
# 0.99        7
# 0.39        7
# 0.54        7
# 0.60        6
# 0.48        4
# Name: dst_host_rerror_rate, Length: 101, dtype: int64
# ------------
# Counts for dst_host_srv_rerror_rate:
# 0.00    21349
# 1.00     2617
# 0.01      253
# 0.02      124
# 0.03       78
#         ...
# 0.39        1
# 0.21        1
# 0.44        1
# 0.43        1
# 0.46        1
# Name: dst_host_srv_rerror_rate, Length: 100, dtype: int64
# ------------
# Counts for class:
# normal     13449
# anomaly    11743
# Name: class, dtype: int64
# ------------

# %% [markdown]
# #Attribute Analyses and Input selection

# %%
intrusion_data.describe()
# Out:
#            duration     src_bytes     dst_bytes          land  wrong_fragment  \
# count  25192.000000  2.519200e+04  2.519200e+04  25192.000000    25192.000000
# mean     305.054104  2.433063e+04  3.491847e+03      0.000079        0.023738
# std     2686.555640  2.410805e+06  8.883072e+04      0.008910        0.260221
# min        0.000000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 25%        0.000000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 50%        0.000000  4.400000e+01  0.000000e+00      0.000000        0.000000
# 75%        0.000000  2.790000e+02  5.302500e+02      0.000000        0.000000
# max    42862.000000  3.817091e+08  5.151385e+06      1.000000        3.000000
#
#             urgent           hot  num_failed_logins     logged_in  \
# count  25192.00000  25192.000000       25192.000000  25192.000000
# mean       0.00004      0.198039           0.001191      0.394768
# std        0.00630      2.154202           0.045418      0.488811
# min        0.00000      0.000000           0.000000      0.000000
# 25%        0.00000      0.000000           0.000000      0.000000
# 50%        0.00000      0.000000           0.000000      0.000000
# 75%        0.00000      0.000000           0.000000      1.000000
# max        1.00000     77.000000           4.000000      1.000000
#
#        num_compromised  ...  dst_host_srv_count  dst_host_same_srv_rate  \
# count     25192.000000  ...        25192.000000            25192.000000
# mean          0.227850  ...          115.063036                0.519791
# std          10.417352  ...          110.646850                0.448944
# min           0.000000  ...            0.000000                0.000000
# 25%           0.000000  ...           10.000000                0.050000
# 50%           0.000000  ...           61.000000                0.510000
# 75%           0.000000  ...          255.000000                1.000000
# max         884.000000  ...          255.000000                1.000000
#
#        dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# count            25192.000000                 25192.000000
# mean                 0.082539                     0.147453
# std                  0.187191                     0.308367
# min                  0.000000                     0.000000
# 25%                  0.000000                     0.000000
# 50%                  0.030000                     0.000000
# 75%                  0.070000                     0.060000
# max                  1.000000                     1.000000
#
#        dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# count                 25192.000000          25192.000000
# mean                      0.031844              0.285800
# std                       0.110575              0.445316
# min                       0.000000              0.000000
# 25%                       0.000000              0.000000
# 50%                       0.000000              0.000000
# 75%                       0.020000              1.000000
# max                       1.000000              1.000000
#
#        dst_host_srv_serror_rate  dst_host_rerror_rate  \
# count              25192.000000          25192.000000
# mean                   0.279846              0.117800
# std                    0.446075              0.305869
# min                    0.000000              0.000000
# 25%                    0.000000              0.000000
# 50%                    0.000000              0.000000
# 75%                    1.000000              0.000000
# max                    1.000000              1.000000
#
#        dst_host_srv_rerror_rate   class_label
# count              25192.000000  25192.000000
# mean                   0.118769      0.466140
# std                    0.317333      0.498862
# min                    0.000000      0.000000
# 25%                    0.000000      0.000000
# 50%                    0.000000      0.000000
# 75%                    0.000000      1.000000
# max                    1.000000      1.000000
#
# [8 rows x 39 columns]

# %%
intrusion_data = pd.read_csv('Train_data.csv')

# %%
intrusion_data_right = intrusion_data
intrusion_data_right['class_label'] = (intrusion_data_right['class'] == 'anomaly').astype(int)
intrusion_data_right = intrusion_data_right.drop(['class'], axis=1)
intrusion_data_right
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp  ftp_data    SF        491          0     0
# 1             0           udp     other    SF        146          0     0
# 2             0           tcp   private    S0          0          0     0
# 3             0           tcp      http    SF        232       8153     0
# 4             0           tcp      http    SF        199        420     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 25187         0           tcp      exec  RSTO          0          0     0
# 25188         0           tcp  ftp_data    SF        334          0     0
# 25189         0           tcp   private   REJ          0          0     0
# 25190         0           tcp      nnsp    S0          0          0     0
# 25191         0           tcp    finger    S0          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0                   0       0    0  ...                  25
# 1                   0       0    0  ...                   1
# 2                   0       0    0  ...                  26
# 3                   0       0    0  ...                 255
# 4                   0       0    0  ...                 255
# ...               ...     ...  ...  ...                 ...
# 25187               0       0    0  ...                   7
# 25188               0       0    0  ...                  39
# 25189               0       0    0  ...                  13
# 25190               0       0    0  ...                  20
# 25191               0       0    0  ...                  49
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                        0.17                    0.03
# 1                        0.00                    0.60
# 2                        0.10                    0.05
# 3                        1.00                    0.00
# 4                        1.00                    0.00
# ...                       ...                     ...
# 25187                    0.03                    0.06
# 25188                    1.00                    0.00
# 25189                    0.05                    0.07
# 25190                    0.08                    0.06
# 25191                    0.19                    0.03
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                             0.17                         0.00
# 1                             0.88                         0.00
# 2                             0.00                         0.00
# 3                             0.03                         0.04
# 4                             0.00                         0.00
# ...                            ...                          ...
# 25187                         0.00                         0.00
# 25188                         1.00                         0.18
# 25189                         0.00                         0.00
# 25190                         0.00                         0.00
# 25191                         0.01                         0.00
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                      0.00                      0.00                  0.05
# 1                      0.00                      0.00                  0.00
# 2                      1.00                      1.00                  0.00
# 3                      0.03                      0.01                  0.00
# 4                      0.00                      0.00                  0.00
# ...                     ...                       ...                   ...
# 25187                  0.00                      0.00                  1.00
# 25188                  0.00                      0.00                  0.00
# 25189                  0.00                      0.00                  1.00
# 25190                  1.00                      1.00                  0.00
# 25191                  1.00                      1.00                  0.00
#
#        dst_host_srv_rerror_rate  class_label
# 0                          0.00            0
# 1                          0.00            0
# 2                          0.00            1
# 3                          0.01            0
# 4                          0.00            0
# ...                         ...          ...
# 25187                      1.00            1
# 25188                      0.00            1
# 25189                      1.00            1
# 25190                      0.00            1
# 25191                      0.00            1
#
# [25192 rows x 42 columns]

# %%
int_data_no_strings = intrusion_data_right.select_dtypes(exclude=['object'])
int_data_no_strings
# Out:
#        duration  src_bytes  dst_bytes  land  wrong_fragment  urgent  hot  \
# 0             0        491          0     0               0       0    0
# 1             0        146          0     0               0       0    0
# 2             0          0          0     0               0       0    0
# 3             0        232       8153     0               0       0    0
# 4             0        199        420     0               0       0    0
# ...         ...        ...        ...   ...             ...     ...  ...
# 25187         0          0          0     0               0       0    0
# 25188         0        334          0     0               0       0    0
# 25189         0          0          0     0               0       0    0
# 25190         0          0          0     0               0       0    0
# 25191         0          0          0     0               0       0    0
#
#        num_failed_logins  logged_in  num_compromised  ...  dst_host_srv_count  \
# 0                      0          0                0  ...                  25
# 1                      0          0                0  ...                   1
# 2                      0          0                0  ...                  26
# 3                      0          1                0  ...                 255
# 4                      0          1                0  ...                 255
# ...                  ...        ...              ...  ...                 ...
# 25187                  0          0                0  ...                   7
# 25188                  0          1                0  ...                  39
# 25189                  0          0                0  ...                  13
# 25190                  0          0                0  ...                  20
# 25191                  0          0                0  ...                  49
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                        0.17                    0.03
# 1                        0.00                    0.60
# 2                        0.10                    0.05
# 3                        1.00                    0.00
# 4                        1.00                    0.00
# ...                       ...                     ...
# 25187                    0.03                    0.06
# 25188                    1.00                    0.00
# 25189                    0.05                    0.07
# 25190                    0.08                    0.06
# 25191                    0.19                    0.03
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                             0.17                         0.00
# 1                             0.88                         0.00
# 2                             0.00                         0.00
# 3                             0.03                         0.04
# 4                             0.00                         0.00
# ...                            ...                          ...
# 25187                         0.00                         0.00
# 25188                         1.00                         0.18
# 25189                         0.00                         0.00
# 25190                         0.00                         0.00
# 25191                         0.01                         0.00
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                      0.00                      0.00                  0.05
# 1                      0.00                      0.00                  0.00
# 2                      1.00                      1.00                  0.00
# 3                      0.03                      0.01                  0.00
# 4                      0.00                      0.00                  0.00
# ...                     ...                       ...                   ...
# 25187                  0.00                      0.00                  1.00
# 25188                  0.00                      0.00                  0.00
# 25189                  0.00                      0.00                  1.00
# 25190                  1.00                      1.00                  0.00
# 25191                  1.00                      1.00                  0.00
#
#        dst_host_srv_rerror_rate  class_label
# 0                          0.00            0
# 1                          0.00            0
# 2                          0.00            1
# 3                          0.01            0
# 4                          0.00            0
# ...                         ...          ...
# 25187                      1.00            1
# 25188                      0.00            1
# 25189                      1.00            1
# 25190                      0.00            1
# 25191                      0.00            1
#
# [25192 rows x 39 columns]

# %%
from sklearn.feature_selection import mutual_info_classif

X = int_data_no_strings.drop('class_label', axis=1)
y = int_data_no_strings['class_label']

mutual_info = mutual_info_classif(X, y)
attribute_info_gain = pd.Series(mutual_info, index=X.columns)

top_ten_attributes = attribute_info_gain.nlargest(10)

print(top_ten_attributes)
# Out:
# src_bytes                   0.565168
# dst_bytes                   0.438556
# diff_srv_rate               0.357038
# same_srv_rate               0.352661
# dst_host_srv_count          0.328747
# dst_host_same_srv_rate      0.306950
# dst_host_diff_srv_rate      0.285171
# dst_host_srv_serror_rate    0.281457
# logged_in                   0.280264
# dst_host_serror_rate        0.278541
# dtype: float64

# %%
int_corr = int_data_no_strings[['src_bytes','dst_bytes','diff_srv_rate','same_srv_rate','dst_host_srv_count','dst_host_same_srv_rate','dst_host_diff_srv_rate','logged_in','dst_host_serror_rate','dst_host_srv_serror_rate', 'class_label']]

# %% [markdown]
# # Splitting Data

# %%
top_10_info_gain = int_data_no_strings[['src_bytes','dst_bytes','diff_srv_rate','same_srv_rate','dst_host_srv_count','dst_host_same_srv_rate','dst_host_diff_srv_rate','logged_in','dst_host_serror_rate','dst_host_srv_serror_rate', 'class_label']]

# %%
from sklearn.model_selection import train_test_split
X = top_10_info_gain.drop(["class_label"], axis=1)
y = top_10_info_gain["class_label"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Get the last two hundred samples from the test  to be the future data samples
futureSample_X = X_test[-200:]
futureSample_y = y_test[-200:]

# Remove the last two hundred samples from the test dataset
X_test = X_test[0:-200]
y_test = y_test[0:-200]

# %%
y_train.value_counts()
# Out:
# 0    10758
# 1     9395
# Name: class_label, dtype: int64

# %% [markdown]
# #Naive Bayes

# %% [markdown]
# ##Hyper Parameter Optimisation

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV

# Define the parameter grid to search
param_grid = {
    'var_smoothing': [1e-9, 1e-8, 1e-7, 1e-6, 1e-5]
}

# Create a Gaussian Naive Bayes classifier
GNB_classifier = GaussianNB()

# Instantiate GridSearchCV with the classifier, parameter grid, and cross-validation strategy
grid_search = GridSearchCV(estimator=GNB_classifier, param_grid=param_grid, cv=5, n_jobs=-1)

# Perform the grid search on the training data
grid_search.fit(X_train, y_train)

# Print the best hyperparameters and corresponding accuracy score
print("Best Hyperparameters: ", grid_search.best_params_)
print("Best Accuracy Score: ", grid_search.best_score_)
# Out:
# Best Hyperparameters:  {'var_smoothing': 1e-09}
# Best Accuracy Score:  0.8465735955772047

# %% [markdown]
# ## Train Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
GNB_classifier = GaussianNB()
GNB_classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
# Predict the class labels of samples in the test dataset
y_pred_GNB = GNB_classifier.predict(X_test)

# %%
score_test = accuracy_score(y_test, y_pred_GNB)
print (score_test)
# Out:
# 0.8466625335813185

# %%
precision_test = precision_score(y_test, y_pred_GNB, average='macro')
print (precision_test)
# Out:
# 0.8482477176153813

# %%
recall_test = recall_score(y_test, y_pred_GNB, average='macro')
print (recall_test)
# Out:
# 0.8495179477109553

# %%
f1_test =  f1_score(y_test, y_pred_GNB, average='macro')
print(f1_test)
# Out:
# 0.846615206588184

# %%
mat = confusion_matrix(y_test, y_pred_GNB)
class_names = ["Not Expired", "Expired"]
plt.figure(figsize=(8, 6))
sns.heatmap(mat, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix (GNB)")
plt.show()

# %%
report = classification_report(y_test, y_pred_GNB)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.81      0.85      2587
#            1       0.80      0.89      0.84      2252
#
#     accuracy                           0.85      4839
#    macro avg       0.85      0.85      0.85      4839
# weighted avg       0.85      0.85      0.85      4839

# %% [markdown]
# ## ROC Curve

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Get the probabilities of each class.
y_probs = GNB_classifier.predict_proba(X_test)

# The 'positive' class value is 1, so we want the probabilities of the class being 1.
# i.e., the second column of the array.
y_probs_class_1 = y_probs[:,1]

auc = roc_auc_score(y_test, y_probs_class_1)
print('The AUC is {:.3f}'.format(auc)) # uses string formatting to get 3 decimal places.

fpr, tpr, thresholds = roc_curve(y_test, y_probs_class_1, pos_label=1)

print("Threshold\tTPR vs FPR")
for f, p, t in zip(fpr, tpr, thresholds):
    print("{:.3f}\t{:.3f} vs {:.3f}".format(t, p, f))

# Here is some code to plot the ROC curve.
# Follows the example at https://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html#sphx-glr-auto-examples-model-selection-plot-roc-py

import matplotlib.pyplot as plt
plt.figure()
lw = 2 # the line width
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--') # The dashed line for random choice
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (GNB)')
plt.legend(loc="lower right")
plt.show()
# Out:
# The AUC is 0.906
# Threshold	TPR vs FPR
# 2.000	0.000 vs 0.000
# 1.000	0.001 vs 0.001
# 0.940	0.001 vs 0.005
# 0.832	0.001 vs 0.005
# 0.832	0.004 vs 0.005
# 0.832	0.007 vs 0.005
# 0.832	0.009 vs 0.005
# 0.832	0.011 vs 0.005
# 0.832	0.012 vs 0.005
# 0.832	0.014 vs 0.005
# 0.832	0.014 vs 0.005
# 0.832	0.016 vs 0.005
# 0.832	0.016 vs 0.005
# 0.832	0.017 vs 0.005
# 0.832	0.018 vs 0.005
# 0.832	0.020 vs 0.005
# 0.832	0.021 vs 0.005
# 0.832	0.024 vs 0.005
# 0.832	0.024 vs 0.005
# 0.831	0.034 vs 0.005
# 0.831	0.035 vs 0.005
# 0.831	0.036 vs 0.005
# 0.820	0.329 vs 0.046
# 0.820	0.330 vs 0.046
# 0.820	0.331 vs 0.047
# 0.820	0.333 vs 0.047
# 0.820	0.334 vs 0.047
# 0.820	0.335 vs 0.047
# 0.820	0.336 vs 0.047
# 0.820	0.339 vs 0.047
# 0.820	0.340 vs 0.047
# 0.820	0.340 vs 0.047
# 0.820	0.341 vs 0.047
# 0.820	0.343 vs 0.047
# 0.820	0.343 vs 0.048
# 0.820	0.345 vs 0.048
# 0.820	0.346 vs 0.048
# 0.820	0.347 vs 0.048
# 0.820	0.348 vs 0.048
# 0.820	0.348 vs 0.048
# 0.820	0.349 vs 0.048
# 0.820	0.351 vs 0.048
# 0.820	0.353 vs 0.048
# 0.820	0.353 vs 0.048
# 0.820	0.353 vs 0.048
# 0.820	0.353 vs 0.049
# 0.820	0.355 vs 0.049
# 0.820	0.355 vs 0.049
# 0.820	0.356 vs 0.049
# 0.820	0.356 vs 0.049
# 0.819	0.357 vs 0.049
# 0.819	0.357 vs 0.050
# 0.819	0.357 vs 0.050
# 0.819	0.357 vs 0.051
# 0.818	0.358 vs 0.051
# 0.818	0.358 vs 0.053
# 0.818	0.359 vs 0.053
# 0.818	0.360 vs 0.053
# 0.818	0.360 vs 0.054
# 0.818	0.361 vs 0.054
# 0.818	0.363 vs 0.054
# 0.818	0.364 vs 0.054
# 0.818	0.365 vs 0.054
# 0.818	0.366 vs 0.054
# 0.818	0.369 vs 0.054
# 0.818	0.369 vs 0.054
# 0.818	0.372 vs 0.054
# 0.818	0.372 vs 0.054
# 0.818	0.379 vs 0.054
# 0.818	0.380 vs 0.054
# 0.818	0.381 vs 0.054
# 0.818	0.381 vs 0.055
# 0.818	0.382 vs 0.055
# 0.817	0.382 vs 0.056
# 0.817	0.383 vs 0.056
# 0.816	0.383 vs 0.057
# 0.816	0.383 vs 0.057
# 0.816	0.383 vs 0.058
# 0.816	0.384 vs 0.058
# 0.816	0.384 vs 0.058
# 0.816	0.385 vs 0.058
# 0.816	0.385 vs 0.059
# 0.816	0.386 vs 0.059
# 0.816	0.386 vs 0.059
# 0.816	0.387 vs 0.059
# 0.816	0.388 vs 0.059
# 0.816	0.389 vs 0.059
# 0.816	0.391 vs 0.059
# 0.816	0.392 vs 0.059
# 0.816	0.393 vs 0.059
# 0.816	0.393 vs 0.060
# 0.816	0.393 vs 0.060
# 0.816	0.393 vs 0.060
# 0.816	0.394 vs 0.060
# 0.816	0.399 vs 0.060
# 0.816	0.400 vs 0.060
# 0.816	0.401 vs 0.060
# 0.816	0.401 vs 0.060
# 0.816	0.405 vs 0.060
# 0.816	0.405 vs 0.061
# 0.816	0.408 vs 0.061
# 0.816	0.408 vs 0.061
# 0.816	0.408 vs 0.061
# 0.816	0.408 vs 0.061
# 0.815	0.411 vs 0.061
# 0.815	0.411 vs 0.062
# 0.815	0.412 vs 0.062
# 0.815	0.412 vs 0.064
# 0.815	0.413 vs 0.064
# 0.815	0.413 vs 0.065
# 0.815	0.413 vs 0.065
# 0.814	0.413 vs 0.066
# 0.814	0.416 vs 0.066
# 0.733	0.815 vs 0.137
# 0.732	0.815 vs 0.138
# 0.730	0.816 vs 0.138
# 0.729	0.817 vs 0.138
# 0.728	0.817 vs 0.139
# 0.728	0.817 vs 0.139
# 0.725	0.817 vs 0.140
# 0.725	0.818 vs 0.140
# 0.725	0.818 vs 0.141
# 0.725	0.818 vs 0.141
# 0.722	0.818 vs 0.142
# 0.722	0.819 vs 0.142
# 0.721	0.821 vs 0.142
# 0.721	0.821 vs 0.143
# 0.720	0.821 vs 0.143
# 0.720	0.821 vs 0.143
# 0.720	0.822 vs 0.143
# 0.718	0.822 vs 0.144
# 0.715	0.823 vs 0.144
# 0.714	0.824 vs 0.144
# 0.712	0.825 vs 0.144
# 0.710	0.825 vs 0.145
# 0.709	0.826 vs 0.145
# 0.709	0.826 vs 0.145
# 0.707	0.826 vs 0.145
# 0.707	0.826 vs 0.145
# 0.706	0.827 vs 0.145
# 0.705	0.827 vs 0.147
# 0.702	0.829 vs 0.147
# 0.701	0.829 vs 0.147
# 0.701	0.829 vs 0.147
# 0.701	0.829 vs 0.147
# 0.700	0.830 vs 0.147
# 0.700	0.830 vs 0.148
# 0.697	0.832 vs 0.148
# 0.697	0.832 vs 0.148
# 0.697	0.832 vs 0.148
# 0.697	0.832 vs 0.148
# 0.696	0.833 vs 0.148
# 0.695	0.833 vs 0.149
# 0.695	0.833 vs 0.149
# 0.693	0.833 vs 0.150
# 0.691	0.835 vs 0.150
# 0.690	0.835 vs 0.151
# 0.690	0.835 vs 0.151
# 0.687	0.835 vs 0.154
# 0.686	0.836 vs 0.154
# 0.683	0.836 vs 0.154
# 0.682	0.837 vs 0.154
# 0.679	0.837 vs 0.156
# 0.675	0.839 vs 0.156
# 0.674	0.839 vs 0.156
# 0.673	0.839 vs 0.156
# 0.672	0.839 vs 0.157
# 0.672	0.840 vs 0.157
# 0.670	0.840 vs 0.157
# 0.669	0.840 vs 0.157
# 0.668	0.840 vs 0.158
# 0.666	0.842 vs 0.158
# 0.664	0.842 vs 0.159
# 0.663	0.843 vs 0.159
# 0.663	0.843 vs 0.160
# 0.658	0.844 vs 0.160
# 0.657	0.844 vs 0.160
# 0.652	0.846 vs 0.160
# 0.652	0.846 vs 0.160
# 0.652	0.847 vs 0.160
# 0.650	0.847 vs 0.161
# 0.650	0.847 vs 0.161
# 0.649	0.847 vs 0.162
# 0.649	0.849 vs 0.162
# 0.646	0.849 vs 0.162
# 0.644	0.849 vs 0.162
# 0.642	0.849 vs 0.164
# 0.640	0.851 vs 0.164
# 0.640	0.851 vs 0.165
# 0.640	0.851 vs 0.165
# 0.638	0.851 vs 0.166
# 0.638	0.852 vs 0.166
# 0.637	0.852 vs 0.167
# 0.636	0.852 vs 0.167
# 0.636	0.852 vs 0.167
# 0.635	0.854 vs 0.167
# 0.635	0.854 vs 0.168
# 0.634	0.854 vs 0.168
# 0.632	0.854 vs 0.169
# 0.629	0.855 vs 0.169
# 0.629	0.855 vs 0.170
# 0.629	0.856 vs 0.170
# 0.628	0.856 vs 0.170
# 0.626	0.858 vs 0.170
# 0.419	0.899 vs 0.209
# 0.419	0.901 vs 0.209
# 0.419	0.902 vs 0.209
# 0.413	0.902 vs 0.211
# 0.411	0.902 vs 0.211
# 0.396	0.902 vs 0.215
# 0.396	0.903 vs 0.215
# 0.384	0.903 vs 0.216
# 0.383	0.903 vs 0.216
# 0.368	0.903 vs 0.220
# 0.367	0.904 vs 0.220
# 0.367	0.904 vs 0.221
# 0.365	0.904 vs 0.221
# 0.364	0.904 vs 0.221
# 0.359	0.905 vs 0.221
# 0.359	0.905 vs 0.221
# 0.349	0.906 vs 0.221
# 0.344	0.906 vs 0.223
# 0.341	0.907 vs 0.223
# 0.341	0.907 vs 0.224
# 0.338	0.907 vs 0.224
# 0.337	0.907 vs 0.225
# 0.336	0.909 vs 0.225
# 0.333	0.909 vs 0.225
# 0.328	0.909 vs 0.225
# 0.322	0.909 vs 0.226
# 0.318	0.910 vs 0.226
# 0.312	0.910 vs 0.227
# 0.310	0.912 vs 0.227
# 0.309	0.912 vs 0.227
# 0.308	0.912 vs 0.228
# 0.306	0.913 vs 0.228
# 0.305	0.913 vs 0.229
# 0.302	0.913 vs 0.229
# 0.300	0.913 vs 0.229
# 0.298	0.913 vs 0.229
# 0.297	0.913 vs 0.230
# 0.296	0.914 vs 0.230
# 0.296	0.914 vs 0.230
# 0.295	0.914 vs 0.230
# 0.283	0.914 vs 0.233
# 0.280	0.915 vs 0.233
# 0.265	0.915 vs 0.237
# 0.265	0.916 vs 0.237
# 0.253	0.916 vs 0.238
# 0.251	0.917 vs 0.238
# 0.246	0.917 vs 0.239
# 0.245	0.917 vs 0.239
# 0.244	0.917 vs 0.239
# 0.244	0.918 vs 0.239
# 0.240	0.918 vs 0.240
# 0.239	0.919 vs 0.240
# 0.229	0.919 vs 0.241
# 0.224	0.920 vs 0.241
# 0.223	0.920 vs 0.242
# 0.220	0.920 vs 0.242
# 0.217	0.921 vs 0.242
# 0.206	0.921 vs 0.244
# 0.206	0.921 vs 0.244
# 0.201	0.921 vs 0.245
# 0.193	0.922 vs 0.245
# 0.189	0.922 vs 0.245
# 0.187	0.923 vs 0.245
# 0.186	0.923 vs 0.246
# 0.185	0.924 vs 0.246
# 0.183	0.924 vs 0.247
# 0.181	0.925 vs 0.247
# 0.176	0.925 vs 0.249
# 0.171	0.925 vs 0.249
# 0.159	0.925 vs 0.252
# 0.158	0.926 vs 0.252
# 0.157	0.926 vs 0.252
# 0.157	0.927 vs 0.252
# 0.147	0.927 vs 0.255
# 0.146	0.927 vs 0.255
# 0.144	0.927 vs 0.256
# 0.144	0.928 vs 0.256
# 0.131	0.928 vs 0.259
# 0.127	0.929 vs 0.259
# 0.126	0.932 vs 0.259
# 0.124	0.932 vs 0.260
# 0.121	0.933 vs 0.260
# 0.120	0.933 vs 0.262
# 0.117	0.933 vs 0.262
# 0.115	0.933 vs 0.263
# 0.114	0.933 vs 0.263
# 0.111	0.933 vs 0.264
# 0.111	0.933 vs 0.264
# 0.104	0.933 vs 0.266
# 0.104	0.934 vs 0.266
# 0.098	0.934 vs 0.267
# 0.098	0.934 vs 0.267
# 0.094	0.934 vs 0.269
# 0.093	0.935 vs 0.269
# 0.093	0.935 vs 0.269
# 0.092	0.935 vs 0.269
# 0.089	0.935 vs 0.271
# 0.089	0.937 vs 0.271
# 0.087	0.937 vs 0.271
# 0.085	0.937 vs 0.271
# 0.082	0.938 vs 0.271
# 0.081	0.938 vs 0.271
# 0.078	0.940 vs 0.271
# 0.076	0.940 vs 0.272
# 0.075	0.940 vs 0.272
# 0.074	0.940 vs 0.272
# 0.074	0.941 vs 0.272
# 0.072	0.941 vs 0.274
# 0.072	0.941 vs 0.274
# 0.071	0.941 vs 0.274
# 0.069	0.942 vs 0.274
# 0.068	0.942 vs 0.275
# 0.067	0.943 vs 0.275
# 0.060	0.943 vs 0.278
# 0.058	0.943 vs 0.278
# 0.057	0.943 vs 0.279
# 0.056	0.944 vs 0.279
# 0.055	0.944 vs 0.280
# 0.055	0.944 vs 0.280
# 0.055	0.944 vs 0.281
# 0.053	0.944 vs 0.281
# 0.051	0.944 vs 0.283
# 0.050	0.945 vs 0.283
# 0.049	0.945 vs 0.284
# 0.049	0.945 vs 0.284
# 0.043	0.945 vs 0.288
# 0.042	0.946 vs 0.288
# 0.042	0.946 vs 0.289
# 0.042	0.947 vs 0.289
# 0.041	0.947 vs 0.290
# 0.040	0.948 vs 0.290
# 0.037	0.948 vs 0.291
# 0.036	0.949 vs 0.291
# 0.031	0.949 vs 0.295
# 0.030	0.949 vs 0.295
# 0.028	0.949 vs 0.297
# 0.028	0.950 vs 0.297
# 0.028	0.950 vs 0.298
# 0.028	0.950 vs 0.298
# 0.026	0.950 vs 0.300
# 0.026	0.950 vs 0.300
# 0.025	0.950 vs 0.302
# 0.025	0.951 vs 0.302
# 0.025	0.951 vs 0.304
# 0.025	0.951 vs 0.304
# 0.025	0.951 vs 0.305
# 0.025	0.952 vs 0.305
# 0.024	0.952 vs 0.306
# 0.023	0.952 vs 0.306
# 0.023	0.952 vs 0.308
# 0.022	0.952 vs 0.308
# 0.021	0.952 vs 0.309
# 0.021	0.953 vs 0.309
# 0.020	0.953 vs 0.312
# 0.019	0.953 vs 0.312
# 0.018	0.953 vs 0.312
# 0.018	0.954 vs 0.312
# 0.018	0.954 vs 0.313
# 0.017	0.954 vs 0.313
# 0.016	0.954 vs 0.314
# 0.015	0.955 vs 0.314
# 0.015	0.956 vs 0.314
# 0.015	0.956 vs 0.314
# 0.015	0.956 vs 0.315
# 0.015	0.957 vs 0.315
# 0.014	0.957 vs 0.317
# 0.014	0.957 vs 0.317
# 0.013	0.957 vs 0.319
# 0.012	0.958 vs 0.319
# 0.011	0.958 vs 0.320
# 0.011	0.958 vs 0.320
# 0.011	0.958 vs 0.321
# 0.011	0.959 vs 0.321
# 0.011	0.959 vs 0.321
# 0.011	0.960 vs 0.321
# 0.009	0.960 vs 0.325
# 0.009	0.960 vs 0.325
# 0.009	0.960 vs 0.325
# 0.009	0.960 vs 0.325
# 0.009	0.960 vs 0.326
# 0.008	0.961 vs 0.326
# 0.007	0.961 vs 0.329
# 0.007	0.961 vs 0.329
# 0.006	0.961 vs 0.330
# 0.006	0.963 vs 0.330
# 0.006	0.963 vs 0.332
# 0.006	0.963 vs 0.332
# 0.005	0.963 vs 0.335
# 0.005	0.964 vs 0.335
# 0.005	0.964 vs 0.336
# 0.005	0.964 vs 0.336
# 0.005	0.964 vs 0.336
# 0.005	0.964 vs 0.336
# 0.005	0.964 vs 0.339
# 0.004	0.965 vs 0.339
# 0.004	0.965 vs 0.339
# 0.004	0.965 vs 0.339
# 0.004	0.965 vs 0.340
# 0.004	0.966 vs 0.340
# 0.004	0.966 vs 0.343
# 0.004	0.966 vs 0.343
# 0.004	0.966 vs 0.344
# 0.004	0.966 vs 0.345
# 0.003	0.966 vs 0.347
# 0.003	0.967 vs 0.347
# 0.003	0.967 vs 0.349
# 0.003	0.968 vs 0.349
# 0.003	0.968 vs 0.349
# 0.003	0.968 vs 0.349
# 0.003	0.968 vs 0.350
# 0.003	0.968 vs 0.350
# 0.003	0.968 vs 0.350
# 0.003	0.969 vs 0.350
# 0.002	0.969 vs 0.353
# 0.002	0.970 vs 0.353
# 0.002	0.970 vs 0.354
# 0.002	0.970 vs 0.354
# 0.002	0.970 vs 0.354
# 0.002	0.971 vs 0.354
# 0.002	0.971 vs 0.355
# 0.002	0.971 vs 0.355
# 0.002	0.971 vs 0.358
# 0.002	0.972 vs 0.358
# 0.002	0.972 vs 0.358
# 0.002	0.972 vs 0.358
# 0.001	0.972 vs 0.362
# 0.001	0.972 vs 0.362
# 0.001	0.972 vs 0.362
# 0.001	0.973 vs 0.362
# 0.001	0.973 vs 0.363
# 0.001	0.973 vs 0.363
# 0.001	0.973 vs 0.366
# 0.001	0.974 vs 0.366
# 0.001	0.974 vs 0.366
# 0.001	0.975 vs 0.366
# 0.001	0.975 vs 0.373
# 0.001	0.975 vs 0.373
# 0.000	0.975 vs 0.385
# 0.000	0.976 vs 0.385
# 0.000	0.976 vs 0.386
# 0.000	0.976 vs 0.387
# 0.000	0.976 vs 0.388
# 0.000	0.976 vs 0.388
# 0.000	0.976 vs 0.400
# 0.000	0.976 vs 0.400
# 0.000	0.976 vs 0.407
# 0.000	0.977 vs 0.407
# 0.000	0.977 vs 0.412
# 0.000	0.977 vs 0.413
# 0.000	0.977 vs 0.420
# 0.000	0.978 vs 0.420
# 0.000	0.978 vs 0.421
# 0.000	0.978 vs 0.421
# 0.000	0.978 vs 0.421
# 0.000	0.979 vs 0.421
# 0.000	0.979 vs 0.424
# 0.000	0.979 vs 0.424
# 0.000	0.979 vs 0.424
# 0.000	0.979 vs 0.431
# 0.000	0.979 vs 0.431
# 0.000	0.979 vs 0.437
# 0.000	0.979 vs 0.439
# 0.000	0.979 vs 0.443
# 0.000	0.980 vs 0.443
# 0.000	0.980 vs 0.444
# 0.000	0.980 vs 0.445
# 0.000	0.980 vs 0.448
# 0.000	0.980 vs 0.449
# 0.000	0.980 vs 0.453
# 0.000	0.980 vs 0.454
# 0.000	0.980 vs 0.459
# 0.000	0.980 vs 0.460
# 0.000	0.980 vs 0.462
# 0.000	0.980 vs 0.463
# 0.000	0.980 vs 0.466
# 0.000	0.980 vs 0.467
# 0.000	0.980 vs 0.468
# 0.000	0.980 vs 0.469
# 0.000	0.980 vs 0.470
# 0.000	0.980 vs 0.471
# 0.000	0.980 vs 0.472
# 0.000	0.980 vs 0.472
# 0.000	0.980 vs 0.479
# 0.000	0.980 vs 0.479
# 0.000	0.980 vs 0.481
# 0.000	0.980 vs 0.482
# 0.000	0.980 vs 0.501
# 0.000	0.980 vs 0.502
# 0.000	0.980 vs 0.504
# 0.000	0.980 vs 0.517
# 0.000	0.984 vs 0.517
# 0.000	0.984 vs 0.517
# 0.000	0.984 vs 0.518
# 0.000	0.984 vs 0.519
# 0.000	0.984 vs 0.521
# 0.000	0.984 vs 0.526
# 0.000	0.984 vs 0.528
# 0.000	0.984 vs 0.532
# 0.000	0.984 vs 0.533
# 0.000	0.984 vs 0.534
# 0.000	0.984 vs 0.535
# 0.000	0.984 vs 0.537
# 0.000	0.989 vs 0.537
# 0.000	0.989 vs 0.541
# 0.000	0.989 vs 0.545
# 0.000	0.989 vs 0.546
# 0.000	0.989 vs 0.549
# 0.000	0.989 vs 0.549
# 0.000	0.989 vs 0.550
# 0.000	0.989 vs 0.551
# 0.000	0.989 vs 0.553
# 0.000	0.995 vs 0.553
# 0.000	0.995 vs 0.649
# 0.000	0.995 vs 0.650
# 0.000	0.995 vs 0.654
# 0.000	0.995 vs 0.654
# 0.000	0.995 vs 0.687
# 0.000	0.995 vs 0.687
# 0.000	0.995 vs 0.723
# 0.000	0.995 vs 0.724
# 0.000	0.995 vs 0.765
# 0.000	0.995 vs 0.767
# 0.000	0.995 vs 0.794
# 0.000	0.995 vs 0.795
# 0.000	0.995 vs 0.844
# 0.000	0.995 vs 0.845
# 0.000	0.995 vs 0.939
# 0.000	0.995 vs 0.940
# 0.000	0.995 vs 1.000
# 0.000	0.996 vs 1.000
# 0.000	0.997 vs 1.000
# 0.000	1.000 vs 1.000
# 0.000	1.000 vs 1.000

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Get the probabilities of each class.
y_probs = GNB_classifier.predict_proba(X_test)

# Initialize lists to store TPR and FPR for each class
tpr_list = []
fpr_list = []

# Convert multi-class labels to binary labels for each class and calculate ROC curves
for pos in range(2):
    binary_labels = (y_test == pos).astype(int)
    fpr, tpr, thresholds = roc_curve(binary_labels, y_probs[:, pos], pos_label=1)
    auc = roc_auc_score(binary_labels, y_probs[:, pos])

    # Store TPR and FPR for plotting
    tpr_list.append(tpr)
    fpr_list.append(fpr)

# Plot ROC curves for all classes on the same graph
plt.figure()
lw = 2
colors = ['darkorange', 'green']
labels = ['Class 0', 'Class 1']

for i in range(len(tpr_list)):
    plt.plot(fpr_list[i], tpr_list[i], color=colors[i], lw=lw, label='ROC curve - %s' % (labels[i]))

plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (GNB)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Measuring performance on small unseen set

# %%
solution_validate = GNB_classifier.predict(futureSample_X)

# %%
score_validate = accuracy_score(futureSample_y, solution_validate)
print (score_validate)
# Out:
# 0.815
