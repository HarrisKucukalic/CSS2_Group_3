# %% [markdown]
# # Connect to Google Drive, Import Libraries and Datasets

# %% [markdown]
# ## Connect to drive and check Directory

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd /content/gdrive/Shareddrives/CSS2 - Research /Research Code
# Out:
# /content/gdrive/Shareddrives/CSS2 - Research /Research Code

# %%
# !ls
# Out:
# Angie.ipynb  Harris.ipynb  Samuel.ipynb   Timothy.ipynb
# desktop.ini  Isaac.ipynb   Test_data.csv  Train_data.csv

# %% [markdown]
# ## Import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_theme(rc={"figure.dpi":120, 'savefig.dpi':120})

# sklearn
import sklearn as sk
from sklearn import *
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import *
# DT
from sklearn.tree import DecisionTreeClassifier
# kNN
from sklearn.neighbors import KNeighborsClassifier
# RF
from sklearn.ensemble import RandomForestClassifier
# SVM
from sklearn.svm import SVC
# NN (FNN - Binary classification)
import tensorflow as tf
from keras.layers import Dense, Dropout

# %% [markdown]
# ## Intrusion Data

# %%
intrusion_data = pd.read_csv('Train_data.csv')
intrusion_data
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp  ftp_data    SF        491          0     0
# 1             0           udp     other    SF        146          0     0
# 2             0           tcp   private    S0          0          0     0
# 3             0           tcp      http    SF        232       8153     0
# 4             0           tcp      http    SF        199        420     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 25187         0           tcp      exec  RSTO          0          0     0
# 25188         0           tcp  ftp_data    SF        334          0     0
# 25189         0           tcp   private   REJ          0          0     0
# 25190         0           tcp      nnsp    S0          0          0     0
# 25191         0           tcp    finger    S0          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0                   0       0    0  ...                  25
# 1                   0       0    0  ...                   1
# 2                   0       0    0  ...                  26
# 3                   0       0    0  ...                 255
# 4                   0       0    0  ...                 255
# ...               ...     ...  ...  ...                 ...
# 25187               0       0    0  ...                   7
# 25188               0       0    0  ...                  39
# 25189               0       0    0  ...                  13
# 25190               0       0    0  ...                  20
# 25191               0       0    0  ...                  49
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                        0.17                    0.03
# 1                        0.00                    0.60
# 2                        0.10                    0.05
# 3                        1.00                    0.00
# 4                        1.00                    0.00
# ...                       ...                     ...
# 25187                    0.03                    0.06
# 25188                    1.00                    0.00
# 25189                    0.05                    0.07
# 25190                    0.08                    0.06
# 25191                    0.19                    0.03
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                             0.17                         0.00
# 1                             0.88                         0.00
# 2                             0.00                         0.00
# 3                             0.03                         0.04
# 4                             0.00                         0.00
# ...                            ...                          ...
# 25187                         0.00                         0.00
# 25188                         1.00                         0.18
# 25189                         0.00                         0.00
# 25190                         0.00                         0.00
# 25191                         0.01                         0.00
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                      0.00                      0.00                  0.05
# 1                      0.00                      0.00                  0.00
# 2                      1.00                      1.00                  0.00
# 3                      0.03                      0.01                  0.00
# 4                      0.00                      0.00                  0.00
# ...                     ...                       ...                   ...
# 25187                  0.00                      0.00                  1.00
# 25188                  0.00                      0.00                  0.00
# 25189                  0.00                      0.00                  1.00
# 25190                  1.00                      1.00                  0.00
# 25191                  1.00                      1.00                  0.00
#
#        dst_host_srv_rerror_rate    class
# 0                          0.00   normal
# 1                          0.00   normal
# 2                          0.00  anomaly
# 3                          0.01   normal
# 4                          0.00   normal
# ...                         ...      ...
# 25187                      1.00  anomaly
# 25188                      0.00  anomaly
# 25189                      1.00  anomaly
# 25190                      0.00  anomaly
# 25191                      0.00  anomaly
#
# [25192 rows x 42 columns]

# %%
intrusion_data['class'].value_counts()
# Out:
# normal     13449
# anomaly    11743
# Name: class, dtype: int64

# %%
value_counts = intrusion_data['class'].value_counts()
total_values = len(intrusion_data['class'].dropna())
percentages = (value_counts / total_values) * 100
print(percentages)
# Out:
# normal     53.385996
# anomaly    46.614004
# Name: class, dtype: float64

# %% [markdown]
# # Preprocessing

# %%
total_rows = len(intrusion_data)

missing_values = intrusion_data.isna().sum()

percentage_missing = (missing_values / total_rows) * 100
percentage_missing = percentage_missing.round(2)
print(percentage_missing)
# Out:
# duration                       0.0
# protocol_type                  0.0
# service                        0.0
# flag                           0.0
# src_bytes                      0.0
# dst_bytes                      0.0
# land                           0.0
# wrong_fragment                 0.0
# urgent                         0.0
# hot                            0.0
# num_failed_logins              0.0
# logged_in                      0.0
# num_compromised                0.0
# root_shell                     0.0
# su_attempted                   0.0
# num_root                       0.0
# num_file_creations             0.0
# num_shells                     0.0
# num_access_files               0.0
# num_outbound_cmds              0.0
# is_host_login                  0.0
# is_guest_login                 0.0
# count                          0.0
# srv_count                      0.0
# serror_rate                    0.0
# srv_serror_rate                0.0
# rerror_rate                    0.0
# srv_rerror_rate                0.0
# same_srv_rate                  0.0
# diff_srv_rate                  0.0
# srv_diff_host_rate             0.0
# dst_host_count                 0.0
# dst_host_srv_count             0.0
# dst_host_same_srv_rate         0.0
# dst_host_diff_srv_rate         0.0
# dst_host_same_src_port_rate    0.0
# dst_host_srv_diff_host_rate    0.0
# dst_host_serror_rate           0.0
# dst_host_srv_serror_rate       0.0
# dst_host_rerror_rate           0.0
# dst_host_srv_rerror_rate       0.0
# class                          0.0
# class_label                    0.0
# dtype: float64

# %% [markdown]
# ## Testing Data

# %%
for column in intrusion_data.columns:
    print(f"Counts for {column}:")
    print(intrusion_data[column].value_counts())
    print("------------")
# Out:
# Counts for duration:
# 0        23168
# 1          374
# 2          165
# 3          102
# 4           75
#          ...
# 17025        1
# 12892        1
# 584          1
# 10774        1
# 322          1
# Name: duration, Length: 758, dtype: int64
# ------------
# Counts for protocol_type:
# tcp     20526
# udp      3011
# icmp     1655
# Name: protocol_type, dtype: int64
# ------------
# Counts for service:
# http         8003
# private      4351
# domain_u     1820
# smtp         1449
# ftp_data     1396
#              ...
# urh_i           4
# red_i           3
# pm_dump         3
# tim_i           2
# http_8001       1
# Name: service, Length: 66, dtype: int64
# ------------
# Counts for flag:
# SF        14973
# S0         7009
# REJ        2216
# RSTR        497
# RSTO        304
# S1           88
# SH           43
# RSTOS0       21
# S2           21
# S3           15
# OTH           5
# Name: flag, dtype: int64
# ------------
# Counts for src_bytes:
# 0        9866
# 8         738
# 1         480
# 44        467
# 45        416
#          ...
# 3724        1
# 44788       1
# 1205        1
# 827         1
# 2896        1
# Name: src_bytes, Length: 1665, dtype: int64
# ------------
# Counts for dst_bytes:
# 0        13574
# 105        309
# 8314       175
# 44         115
# 42         105
#          ...
# 752          1
# 23681        1
# 6393         1
# 1044         1
# 2257         1
# Name: dst_bytes, Length: 3922, dtype: int64
# ------------
# Counts for land:
# 0    25190
# 1        2
# Name: land, dtype: int64
# ------------
# Counts for wrong_fragment:
# 0    24968
# 3      187
# 1       37
# Name: wrong_fragment, dtype: int64
# ------------
# Counts for urgent:
# 0    25191
# 1        1
# Name: urgent, dtype: int64
# ------------
# Counts for hot:
# 0     24672
# 2       200
# 1        78
# 30       55
# 28       52
# 4        37
# 6        26
# 5        17
# 22       13
# 24        9
# 19        8
# 3         7
# 18        6
# 14        3
# 7         2
# 15        1
# 25        1
# 77        1
# 17        1
# 11        1
# 20        1
# 12        1
# Name: hot, dtype: int64
# ------------
# Counts for num_failed_logins:
# 0    25169
# 1       19
# 2        2
# 3        1
# 4        1
# Name: num_failed_logins, dtype: int64
# ------------
# Counts for logged_in:
# 0    15247
# 1     9945
# Name: logged_in, dtype: int64
# ------------
# Counts for num_compromised:
# 0      24920
# 1        194
# 2         21
# 4         13
# 6          8
# 3          7
# 5          5
# 7          2
# 151        2
# 12         2
# 83         1
# 558        1
# 789        1
# 520        1
# 884        1
# 217        1
# 371        1
# 193        1
# 31         1
# 13         1
# 157        1
# 9          1
# 110        1
# 462        1
# 107        1
# 38         1
# 19         1
# 457        1
# Name: num_compromised, dtype: int64
# ------------
# Counts for root_shell:
# 0    25153
# 1       39
# Name: root_shell, dtype: int64
# ------------
# Counts for su_attempted:
# 0    25171
# 2       13
# 1        8
# Name: su_attempted, dtype: int64
# ------------
# Counts for num_root:
# 0      25058
# 1         47
# 9         24
# 6         23
# 2         10
# 5          6
# 4          2
# 3          2
# 14         1
# 100        1
# 975        1
# 10         1
# 572        1
# 867        1
# 191        1
# 91         1
# 247        1
# 146        1
# 417        1
# 629        1
# 7          1
# 179        1
# 54         1
# 38         1
# 151        1
# 121        1
# 512        1
# 508        1
# Name: num_root, dtype: int64
# ------------
# Counts for num_file_creations:
# 0     25126
# 1        37
# 2         7
# 4         3
# 8         2
# 18        2
# 5         2
# 21        1
# 11        1
# 20        1
# 3         1
# 40        1
# 17        1
# 6         1
# 14        1
# 19        1
# 29        1
# 13        1
# 15        1
# 38        1
# Name: num_file_creations, dtype: int64
# ------------
# Counts for num_shells:
# 0    25183
# 1        9
# Name: num_shells, dtype: int64
# ------------
# Counts for num_access_files:
# 0    25113
# 1       65
# 2        8
# 3        2
# 5        2
# 4        1
# 8        1
# Name: num_access_files, dtype: int64
# ------------
# Counts for num_outbound_cmds:
# 0    25192
# Name: num_outbound_cmds, dtype: int64
# ------------
# Counts for is_host_login:
# 0    25192
# Name: is_host_login, dtype: int64
# ------------
# Counts for is_guest_login:
# 0    24962
# 1      230
# Name: is_guest_login, dtype: int64
# ------------
# Counts for count:
# 1      5519
# 2      1934
# 3       769
# 4       696
# 5       597
#        ...
# 410       1
# 318       1
# 353       1
# 481       1
# 328       1
# Name: count, Length: 466, dtype: int64
# ------------
# Counts for srv_count:
# 1      5080
# 2      2538
# 3      1223
# 4      1086
# 5       913
#        ...
# 481       1
# 278       1
# 338       1
# 351       1
# 408       1
# Name: srv_count, Length: 414, dtype: int64
# ------------
# Counts for serror_rate:
# 0.00    17329
# 1.00     6941
# 0.50      122
# 0.07       53
# 0.06       50
#         ...
# 0.26        1
# 0.55        1
# 0.91        1
# 0.59        1
# 0.74        1
# Name: serror_rate, Length: 70, dtype: int64
# ------------
# Counts for srv_serror_rate:
# 0.00    17708
# 1.00     7003
# 0.50       94
# 0.33       51
# 0.25       42
# 0.20       32
# 0.05       26
# 0.17       22
# 0.03       20
# 0.04       20
# 0.07       16
# 0.02       13
# 0.67       13
# 0.09       10
# 0.10       10
# 0.08       10
# 0.06       10
# 0.12       10
# 0.95        9
# 0.14        9
# 0.11        8
# 0.40        5
# 0.90        4
# 0.22        4
# 0.80        3
# 0.91        3
# 0.89        3
# 0.92        3
# 0.29        2
# 0.76        2
# 0.18        2
# 0.45        1
# 0.13        1
# 0.65        1
# 0.75        1
# 0.39        1
# 0.59        1
# 0.46        1
# 0.88        1
# 0.83        1
# 0.26        1
# 0.41        1
# 0.74        1
# 0.01        1
# 0.86        1
# 0.94        1
# 0.93        1
# 0.57        1
# 0.60        1
# 0.34        1
# 0.36        1
# 0.55        1
# 0.53        1
# 0.78        1
# 0.43        1
# 0.15        1
# Name: srv_serror_rate, dtype: int64
# ------------
# Counts for rerror_rate:
# 0.00    21985
# 1.00     2552
# 0.90       43
# 0.89       39
# 0.91       38
#         ...
# 0.09        1
# 0.44        1
# 0.21        1
# 0.32        1
# 0.57        1
# Name: rerror_rate, Length: 72, dtype: int64
# ------------
# Counts for srv_rerror_rate:
# 0.00    21959
# 1.00     2937
# 0.50       56
# 0.33       32
# 0.25       26
# 0.17       17
# 0.20       16
# 0.04       14
# 0.08       11
# 0.67       11
# 0.14       10
# 0.06       10
# 0.02        9
# 0.05        8
# 0.03        8
# 0.10        8
# 0.07        7
# 0.12        5
# 0.75        5
# 0.62        4
# 0.83        3
# 0.40        3
# 0.29        3
# 0.80        3
# 0.11        3
# 0.43        2
# 0.60        2
# 0.81        2
# 0.64        2
# 0.09        2
# 0.79        2
# 0.71        2
# 0.56        1
# 0.84        1
# 0.74        1
# 0.38        1
# 0.85        1
# 0.15        1
# 0.69        1
# 0.73        1
# 0.76        1
# 0.57        1
# Name: srv_rerror_rate, dtype: int64
# ------------
# Counts for same_srv_rate:
# 1.00    15357
# 0.01      827
# 0.02      710
# 0.06      681
# 0.03      678
#         ...
# 0.78        1
# 0.70        1
# 0.61        1
# 0.82        1
# 0.81        1
# Name: same_srv_rate, Length: 97, dtype: int64
# ------------
# Counts for diff_srv_rate:
# 0.00    15245
# 0.06     3861
# 0.07     1947
# 0.05     1350
# 1.00      663
#         ...
# 0.76        1
# 0.59        1
# 0.77        1
# 0.56        1
# 0.70        1
# Name: diff_srv_rate, Length: 79, dtype: int64
# ------------
# Counts for srv_diff_host_rate:
# 0.00    19517
# 1.00     1559
# 0.01      586
# 0.67      210
# 0.50      193
# 0.12      170
# 0.33      167
# 0.25      164
# 0.02      153
# 0.11      143
# 0.10      138
# 0.29      129
# 0.18      129
# 0.17      128
# 0.08      124
# 0.40      123
# 0.20      122
# 0.14      121
# 0.06      118
# 0.09      112
# 0.07      111
# 0.15      111
# 0.22      111
# 0.13       81
# 0.05       59
# 0.75       58
# 0.19       57
# 0.21       47
# 0.16       46
# 0.23       43
# 0.27       42
# 0.60       41
# 0.03       40
# 0.04       39
# 0.43       34
# 0.30       29
# 0.38       28
# 0.36       21
# 0.80       14
# 0.31       11
# 0.24       11
# 0.44        7
# 0.57        7
# 0.28        6
# 0.42        5
# 0.26        4
# 0.56        4
# 0.45        3
# 0.62        3
# 0.71        3
# 0.32        2
# 0.35        2
# 0.37        2
# 0.83        1
# 0.55        1
# 0.88        1
# 0.47        1
# Name: srv_diff_host_rate, dtype: int64
# ------------
# Counts for dst_host_count:
# 255    14850
# 1        601
# 2        554
# 3        251
# 4        241
#        ...
# 219       11
# 229       10
# 206        9
# 233        8
# 0          1
# Name: dst_host_count, Length: 256, dtype: int64
# ------------
# Counts for dst_host_srv_count:
# 255    7148
# 1      1658
# 2      1041
# 3       556
# 4       516
#        ...
# 188      11
# 204      10
# 220       9
# 221       7
# 0         1
# Name: dst_host_srv_count, Length: 256, dtype: int64
# ------------
# Counts for dst_host_same_srv_rate:
# 1.00    9758
# 0.01    1541
# 0.00    1379
# 0.02    1325
# 0.07    1122
#         ...
# 0.51      33
# 0.37      33
# 0.68      32
# 0.42      30
# 0.66      26
# Name: dst_host_same_srv_rate, Length: 101, dtype: int64
# ------------
# Counts for dst_host_diff_srv_rate:
# 0.00    9343
# 0.07    3448
# 0.06    1917
# 0.01    1881
# 0.05    1436
#         ...
# 0.41       6
# 0.98       6
# 0.88       5
# 0.90       5
# 0.93       3
# Name: dst_host_diff_srv_rate, Length: 101, dtype: int64
# ------------
# Counts for dst_host_same_src_port_rate:
# 0.00    12673
# 0.01     3557
# 1.00     2052
# 0.02     1115
# 0.03      624
#         ...
# 0.63       11
# 0.65       11
# 0.72       10
# 0.66        9
# 0.81        9
# Name: dst_host_same_src_port_rate, Length: 101, dtype: int64
# ------------
# Counts for dst_host_srv_diff_host_rate:
# 0.00    17387
# 0.02     1612
# 0.01     1468
# 0.03      950
# 0.04      870
#         ...
# 0.46        1
# 0.36        1
# 0.42        1
# 0.39        1
# 0.86        1
# Name: dst_host_srv_diff_host_rate, Length: 63, dtype: int64
# ------------
# Counts for dst_host_serror_rate:
# 0.00    16221
# 1.00     6739
# 0.01      680
# 0.02      237
# 0.03      149
#         ...
# 0.28        1
# 0.61        1
# 0.32        1
# 0.83        1
# 0.54        1
# Name: dst_host_serror_rate, Length: 100, dtype: int64
# ------------
# Counts for dst_host_srv_serror_rate:
# 0.00    17005
# 1.00     6862
# 0.01      758
# 0.02      136
# 0.03       32
#         ...
# 0.77        1
# 0.87        1
# 0.84        1
# 0.82        1
# 0.24        1
# Name: dst_host_srv_serror_rate, Length: 88, dtype: int64
# ------------
# Counts for dst_host_rerror_rate:
# 0.00    20688
# 1.00     2069
# 0.01      359
# 0.02      232
# 0.03      110
#         ...
# 0.99        7
# 0.39        7
# 0.54        7
# 0.60        6
# 0.48        4
# Name: dst_host_rerror_rate, Length: 101, dtype: int64
# ------------
# Counts for dst_host_srv_rerror_rate:
# 0.00    21349
# 1.00     2617
# 0.01      253
# 0.02      124
# 0.03       78
#         ...
# 0.39        1
# 0.21        1
# 0.44        1
# 0.43        1
# 0.46        1
# Name: dst_host_srv_rerror_rate, Length: 100, dtype: int64
# ------------
# Counts for class:
# normal     13449
# anomaly    11743
# Name: class, dtype: int64
# ------------
# Counts for class_label:
# 0    13449
# 1    11743
# Name: class_label, dtype: int64
# ------------

# %% [markdown]
# #Attribute Analyses and Input selection

# %% [markdown]
# ## Intrusion data

# %%
intrusion_data.describe()
# Out:
#            duration     src_bytes     dst_bytes          land  wrong_fragment  \
# count  25192.000000  2.519200e+04  2.519200e+04  25192.000000    25192.000000
# mean     305.054104  2.433063e+04  3.491847e+03      0.000079        0.023738
# std     2686.555640  2.410805e+06  8.883072e+04      0.008910        0.260221
# min        0.000000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 25%        0.000000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 50%        0.000000  4.400000e+01  0.000000e+00      0.000000        0.000000
# 75%        0.000000  2.790000e+02  5.302500e+02      0.000000        0.000000
# max    42862.000000  3.817091e+08  5.151385e+06      1.000000        3.000000
#
#             urgent           hot  num_failed_logins     logged_in  \
# count  25192.00000  25192.000000       25192.000000  25192.000000
# mean       0.00004      0.198039           0.001191      0.394768
# std        0.00630      2.154202           0.045418      0.488811
# min        0.00000      0.000000           0.000000      0.000000
# 25%        0.00000      0.000000           0.000000      0.000000
# 50%        0.00000      0.000000           0.000000      0.000000
# 75%        0.00000      0.000000           0.000000      1.000000
# max        1.00000     77.000000           4.000000      1.000000
#
#        num_compromised  ...  dst_host_count  dst_host_srv_count  \
# count     25192.000000  ...    25192.000000        25192.000000
# mean          0.227850  ...      182.532074          115.063036
# std          10.417352  ...       98.993895          110.646850
# min           0.000000  ...        0.000000            0.000000
# 25%           0.000000  ...       84.000000           10.000000
# 50%           0.000000  ...      255.000000           61.000000
# 75%           0.000000  ...      255.000000          255.000000
# max         884.000000  ...      255.000000          255.000000
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# count            25192.000000            25192.000000
# mean                 0.519791                0.082539
# std                  0.448944                0.187191
# min                  0.000000                0.000000
# 25%                  0.050000                0.000000
# 50%                  0.510000                0.030000
# 75%                  1.000000                0.070000
# max                  1.000000                1.000000
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# count                 25192.000000                 25192.000000
# mean                      0.147453                     0.031844
# std                       0.308367                     0.110575
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       0.060000                     0.020000
# max                       1.000000                     1.000000
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# count          25192.000000              25192.000000          25192.000000
# mean               0.285800                  0.279846              0.117800
# std                0.445316                  0.446075              0.305869
# min                0.000000                  0.000000              0.000000
# 25%                0.000000                  0.000000              0.000000
# 50%                0.000000                  0.000000              0.000000
# 75%                1.000000                  1.000000              0.000000
# max                1.000000                  1.000000              1.000000
#
#        dst_host_srv_rerror_rate
# count              25192.000000
# mean                   0.118769
# std                    0.317333
# min                    0.000000
# 25%                    0.000000
# 50%                    0.000000
# 75%                    0.000000
# max                    1.000000
#
# [8 rows x 38 columns]

# %%
intrusion_data = pd.read_csv('Train_data.csv')

# %%
intrusion_data_right = intrusion_data
intrusion_data_right['class_label'] = (intrusion_data_right['class'] == 'anomaly').astype(int)
intrusion_data_right = intrusion_data_right.drop(['class'], axis=1)
intrusion_data_right
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp  ftp_data    SF        491          0     0
# 1             0           udp     other    SF        146          0     0
# 2             0           tcp   private    S0          0          0     0
# 3             0           tcp      http    SF        232       8153     0
# 4             0           tcp      http    SF        199        420     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 25187         0           tcp      exec  RSTO          0          0     0
# 25188         0           tcp  ftp_data    SF        334          0     0
# 25189         0           tcp   private   REJ          0          0     0
# 25190         0           tcp      nnsp    S0          0          0     0
# 25191         0           tcp    finger    S0          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0                   0       0    0  ...                  25
# 1                   0       0    0  ...                   1
# 2                   0       0    0  ...                  26
# 3                   0       0    0  ...                 255
# 4                   0       0    0  ...                 255
# ...               ...     ...  ...  ...                 ...
# 25187               0       0    0  ...                   7
# 25188               0       0    0  ...                  39
# 25189               0       0    0  ...                  13
# 25190               0       0    0  ...                  20
# 25191               0       0    0  ...                  49
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                        0.17                    0.03
# 1                        0.00                    0.60
# 2                        0.10                    0.05
# 3                        1.00                    0.00
# 4                        1.00                    0.00
# ...                       ...                     ...
# 25187                    0.03                    0.06
# 25188                    1.00                    0.00
# 25189                    0.05                    0.07
# 25190                    0.08                    0.06
# 25191                    0.19                    0.03
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                             0.17                         0.00
# 1                             0.88                         0.00
# 2                             0.00                         0.00
# 3                             0.03                         0.04
# 4                             0.00                         0.00
# ...                            ...                          ...
# 25187                         0.00                         0.00
# 25188                         1.00                         0.18
# 25189                         0.00                         0.00
# 25190                         0.00                         0.00
# 25191                         0.01                         0.00
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                      0.00                      0.00                  0.05
# 1                      0.00                      0.00                  0.00
# 2                      1.00                      1.00                  0.00
# 3                      0.03                      0.01                  0.00
# 4                      0.00                      0.00                  0.00
# ...                     ...                       ...                   ...
# 25187                  0.00                      0.00                  1.00
# 25188                  0.00                      0.00                  0.00
# 25189                  0.00                      0.00                  1.00
# 25190                  1.00                      1.00                  0.00
# 25191                  1.00                      1.00                  0.00
#
#        dst_host_srv_rerror_rate  class_label
# 0                          0.00            0
# 1                          0.00            0
# 2                          0.00            1
# 3                          0.01            0
# 4                          0.00            0
# ...                         ...          ...
# 25187                      1.00            1
# 25188                      0.00            1
# 25189                      1.00            1
# 25190                      0.00            1
# 25191                      0.00            1
#
# [25192 rows x 42 columns]

# %%
int_data_no_strings = intrusion_data_right.select_dtypes(exclude=['object'])
int_data_no_strings
# Out:
#        duration  src_bytes  dst_bytes  land  wrong_fragment  urgent  hot  \
# 0             0        491          0     0               0       0    0
# 1             0        146          0     0               0       0    0
# 2             0          0          0     0               0       0    0
# 3             0        232       8153     0               0       0    0
# 4             0        199        420     0               0       0    0
# ...         ...        ...        ...   ...             ...     ...  ...
# 25187         0          0          0     0               0       0    0
# 25188         0        334          0     0               0       0    0
# 25189         0          0          0     0               0       0    0
# 25190         0          0          0     0               0       0    0
# 25191         0          0          0     0               0       0    0
#
#        num_failed_logins  logged_in  num_compromised  ...  dst_host_srv_count  \
# 0                      0          0                0  ...                  25
# 1                      0          0                0  ...                   1
# 2                      0          0                0  ...                  26
# 3                      0          1                0  ...                 255
# 4                      0          1                0  ...                 255
# ...                  ...        ...              ...  ...                 ...
# 25187                  0          0                0  ...                   7
# 25188                  0          1                0  ...                  39
# 25189                  0          0                0  ...                  13
# 25190                  0          0                0  ...                  20
# 25191                  0          0                0  ...                  49
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                        0.17                    0.03
# 1                        0.00                    0.60
# 2                        0.10                    0.05
# 3                        1.00                    0.00
# 4                        1.00                    0.00
# ...                       ...                     ...
# 25187                    0.03                    0.06
# 25188                    1.00                    0.00
# 25189                    0.05                    0.07
# 25190                    0.08                    0.06
# 25191                    0.19                    0.03
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                             0.17                         0.00
# 1                             0.88                         0.00
# 2                             0.00                         0.00
# 3                             0.03                         0.04
# 4                             0.00                         0.00
# ...                            ...                          ...
# 25187                         0.00                         0.00
# 25188                         1.00                         0.18
# 25189                         0.00                         0.00
# 25190                         0.00                         0.00
# 25191                         0.01                         0.00
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                      0.00                      0.00                  0.05
# 1                      0.00                      0.00                  0.00
# 2                      1.00                      1.00                  0.00
# 3                      0.03                      0.01                  0.00
# 4                      0.00                      0.00                  0.00
# ...                     ...                       ...                   ...
# 25187                  0.00                      0.00                  1.00
# 25188                  0.00                      0.00                  0.00
# 25189                  0.00                      0.00                  1.00
# 25190                  1.00                      1.00                  0.00
# 25191                  1.00                      1.00                  0.00
#
#        dst_host_srv_rerror_rate  class_label
# 0                          0.00            0
# 1                          0.00            0
# 2                          0.00            1
# 3                          0.01            0
# 4                          0.00            0
# ...                         ...          ...
# 25187                      1.00            1
# 25188                      0.00            1
# 25189                      1.00            1
# 25190                      0.00            1
# 25191                      0.00            1
#
# [25192 rows x 39 columns]

# %% [markdown]
# #Splitting Data

# %%
top_10_info_gain = intrusion_data[['src_bytes','dst_bytes','diff_srv_rate','same_srv_rate','dst_host_srv_count','dst_host_same_srv_rate','dst_host_diff_srv_rate','logged_in','dst_host_serror_rate','dst_host_srv_serror_rate', 'class_label']]

# %%
top_10_info_gain = int_data_no_strings

# %%
from sklearn.model_selection import train_test_split
X = top_10_info_gain.drop(["class_label"], axis=1)
y = top_10_info_gain["class_label"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Get the last two hundred samples from the test  to be the future data samples
futureSample_X = X_test[-2500:]
futureSample_y = y_test[-2500:]

# Remove the last two hundred samples from the test dataset
X_test = X_test[0:-2500]
y_test = y_test[0:-2500]

# %%
y_train.value_counts()
# Out:
# 0    10702
# 1     9451
# Name: class_label, dtype: int64

# %% [markdown]
# # Decision Tree

# %% [markdown]
# ## Hyper Parameter tunning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# Define the parameter grid to search
param_grid = {
    'criterion': ['entropy', 'gini'],
    'max_depth': [None, 10, 20, 30, 40, 50],
    'min_samples_split': [2, 5, 10, 15, 20],
    'min_samples_leaf': [1, 2, 4, 8, 16]
}

# Create a decision tree classifier
DT_classifier = DecisionTreeClassifier()

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=DT_classifier, param_grid=param_grid, cv=5)

# Perform grid search on the training data
grid_search.fit(X_train_resampled, y_train_resampled)

# Get the best parameters and the best estimator
best_params = grid_search.best_params_
best_classifier = grid_search.best_estimator_
print("Best Hyperparameters:", best_params)

# %% [markdown]
# ## Train Decision Tree

# %%
DT_classifier = DecisionTreeClassifier(criterion='entropy', max_depth=40,
                                       min_samples_leaf=1, min_samples_split=2)
DT_classifier.fit(X_train_resampled, y_train_resampled)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=40)

# %% [markdown]
# ## Measure Decision Tree's performance

# %%
# Predict the class labels of samples in the test dataset
y_pred_DT = DT_classifier.predict(X_test)

# %%
score_test = accuracy_score(y_test, y_pred_DT)
print (score_test)
# Out:
# 0.8783294268058811

# %%
precision_test = precision_score(y_test, y_pred_DT, average='macro')
print (precision_test)
# Out:
# 0.6850950519635571

# %%
recall_test = recall_score(y_test, y_pred_DT, average='macro')
print (recall_test)
# Out:
# 0.7392795414978082

# %%
f1_test =  f1_score(y_test, y_pred_DT, average='macro')
print(f1_test)
# Out:
# 0.7066922835868811

# %%
mat = confusion_matrix(y_test, y_pred_DT)
class_names = ["Not Expired", "Expired"]
plt.figure(figsize=(8, 6))
sns.heatmap(mat, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix (Decision Tree)")
plt.show()

# %%
report = classification_report(y_test, y_pred_DT)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      8445
#            1       0.45      0.52      0.48       941
#
#     accuracy                           0.89      9386
#    macro avg       0.70      0.73      0.71      9386
# weighted avg       0.90      0.89      0.89      9386

# %% [markdown]
# ## ROC Curve

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Get the probabilities of each class.
y_probs = DT_classifier.predict_proba(X_test)

# The 'positive' class value is 1, so we want the probabilities of the class being 1.
# i.e., the second column of the array.
y_probs_class_1 = y_probs[:,1]

auc = roc_auc_score(y_test, y_probs_class_1)
print('The AUC is {:.3f}'.format(auc)) # uses string formatting to get 3 decimal places.

fpr, tpr, thresholds = roc_curve(y_test, y_probs_class_1, pos_label=1)

print("Threshold\tTPR vs FPR")
for f, p, t in zip(fpr, tpr, thresholds):
    print("{:.3f}\t{:.3f} vs {:.3f}".format(t, p, f))

# Here is some code to plot the ROC curve.
# Follows the example at https://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html#sphx-glr-auto-examples-model-selection-plot-roc-py

import matplotlib.pyplot as plt
plt.figure()
lw = 2 # the line width
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--') # The dashed line for random choice
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (Decision Tree)')
plt.legend(loc="lower right")
plt.show()
# Out:
# The AUC is 0.727
# Threshold	TPR vs FPR
# 2.000	0.000 vs 0.000
# 1.000	0.524 vs 0.072
# 0.125	0.525 vs 0.072
# 0.000	1.000 vs 1.000

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Get the probabilities of each class.
y_probs = DT_classifier.predict_proba(X_test)

# Initialize lists to store TPR and FPR for each class
tpr_list = []
fpr_list = []

# Convert multi-class labels to binary labels for each class and calculate ROC curves
for pos in range(2):
    binary_labels = (y_test == pos).astype(int)
    fpr, tpr, thresholds = roc_curve(binary_labels, y_probs[:, pos], pos_label=1)
    auc = roc_auc_score(binary_labels, y_probs[:, pos])

    # Store TPR and FPR for plotting
    tpr_list.append(tpr)
    fpr_list.append(fpr)

# Plot ROC curves for all classes on the same graph
plt.figure()
lw = 2
colors = ['darkorange', 'green']
labels = ['Class 0', 'Class 1']

for i in range(len(tpr_list)):
    plt.plot(fpr_list[i], tpr_list[i], color=colors[i], lw=lw, label='ROC curve - %s' % (labels[i]))

plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (DT)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Measuring performance on small unseen set

# %%
solution_validate = DT_classifier.predict(future_sample_X)

# %%
score_validate = accuracy_score(future_sample_y, solution_validate)
print (score_validate)

# %% [markdown]
# # K Nearest Neighbour

# %% [markdown]
# ## Find best k value

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

# Define the parameter grid (k values to explore)
param_grid = {'n_neighbors': [3, 5, 7, 9, 11, 13, 15, 19, 21, 23, 25, 27, 29, 31]}

# Create kNN classifier
knn = KNeighborsClassifier()

# Initialize GridSearchCV
grid_search = GridSearchCV(knn, param_grid, cv=5)

# Perform grid search
grid_search.fit(X_train_resampled, y_train_resampled)

# Get the best k value
best_k = grid_search.best_params_['n_neighbors']

print("Best k value:", best_k)
# Out:
# Best k value: 3

# %% [markdown]
# ## Train kNN

# %%
KNN_classifier = KNeighborsClassifier(n_neighbors=3)
KNN_classifier.fit(X_train_resampled, y_train_resampled)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ## Measure kNN's performance

# %%
# Predict the class labels of samples in the test dataset
y_pred_KNN = KNN_classifier.predict(X_test)

# %%
score_test = accuracy_score(y_test, y_pred_KNN)
print (score_test)
# Out:
# 0.8546771787769017

# %%
precision_test = precision_score(y_test, y_pred_KNN, average='macro')
print (precision_test)
# Out:
# 0.6691099301332915

# %%
recall_test = recall_score(y_test, y_pred_KNN, average='macro')
print (recall_test)
# Out:
# 0.7799599710321647

# %%
f1_test =  f1_score(y_test, y_pred_KNN, average='macro')
print(f1_test)
# Out:
# 0.7009046984662403

# %%
mat = confusion_matrix(y_test, y_pred_DT)
class_names = ["Not Expired", "Expired"]
plt.figure(figsize=(8, 6))
sns.heatmap(mat, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix (kNN)")
plt.show()

# %%
report = classification_report(y_test, y_pred_KNN)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.90      8445
#            1       0.33      0.64      0.44       941
#
#     accuracy                           0.84      9386
#    macro avg       0.64      0.75      0.67      9386
# weighted avg       0.89      0.84      0.86      9386

# %% [markdown]
# ## ROC Curve

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Get the probabilities of each class.
y_probs = KNN_classifier.predict_proba(X_test)

# The 'positive' class value is 1, so we want the probabilities of the class being 1.
# i.e., the second column of the array.
y_probs_class_1 = y_probs[:,1]

auc = roc_auc_score(y_test, y_probs_class_1)
print('The AUC is {:.3f}'.format(auc)) # uses string formatting to get 3 decimal places.

fpr, tpr, thresholds = roc_curve(y_test, y_probs_class_1, pos_label=1)

print("Threshold\tTPR vs FPR")
for f, p, t in zip(fpr, tpr, thresholds):
    print("{:.3f}\t{:.3f} vs {:.3f}".format(t, p, f))

# Here is some code to plot the ROC curve.
# Follows the example at https://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html#sphx-glr-auto-examples-model-selection-plot-roc-py

import matplotlib.pyplot as plt
plt.figure()
lw = 2 # the line width
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--') # The dashed line for random choice
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (kNN)')
plt.legend(loc="lower right")
plt.show()
# Out:
# The AUC is 0.786
# Threshold	TPR vs FPR
# 2.000	0.000 vs 0.000
# 1.000	0.487 vs 0.069
# 0.667	0.634 vs 0.142
# 0.333	0.734 vs 0.230
# 0.000	1.000 vs 1.000

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Get the probabilities of each class.
y_probs = KNN_classifier.predict_proba(X_test)

# Initialize lists to store TPR and FPR for each class
tpr_list = []
fpr_list = []

# Convert multi-class labels to binary labels for each class and calculate ROC curves
for pos in range(2):
    binary_labels = (y_test == pos).astype(int)
    fpr, tpr, thresholds = roc_curve(binary_labels, y_probs[:, pos], pos_label=1)
    auc = roc_auc_score(binary_labels, y_probs[:, pos])

    # Store TPR and FPR for plotting
    tpr_list.append(tpr)
    fpr_list.append(fpr)

# Plot ROC curves for all classes on the same graph
plt.figure()
lw = 2
colors = ['darkorange', 'green']
labels = ['Class 0', 'Class 1']

for i in range(len(tpr_list)):
    plt.plot(fpr_list[i], tpr_list[i], color=colors[i], lw=lw, label='ROC curve - %s' % (labels[i]))

plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (kNN)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Measuring performance on small unseen set

# %%
solution_validate = KNN_classifier.predict(future_sample_X)

# %%
score_validate = accuracy_score(future_sample_y, solution_validate)
print (score_validate)
# Out:
# 0.9

# %% [markdown]
# # Random Forrest

# %% [markdown]
# ## Hyper Parameter optimization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# Define the parameter grid to search
param_grid = {
    'criterion': ['entropy', 'gini'],
    'n_estimators': [50, 100, 200],  # Number of trees in the forest
    'max_depth': [None, 10, 20],      # Maximum depth of the tree
    'min_samples_split': [2, 5, 10],  # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 4]
}

# Create a decision tree classifier
RF_classifier = RandomForestClassifier()

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=RF_classifier, param_grid=param_grid, cv=5)

# Perform grid search on the training data
grid_search.fit(X_train_resampled, y_train_resampled)

# Get the best parameters and the best estimator
best_params = grid_search.best_params_
best_classifier = grid_search.best_estimator_
print("Best Hyperparameters:", best_params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-140-a67ffdade7ab> in <cell line: 20>()
#      18
#      19 # Perform grid search on the training data
# ---> 20 grid_search.fit(X_train_resampled, y_train_resampled)
#      21
#      22 # Get the best parameters and the best estimator
#
# NameError: name 'X_train_resampled' is not defined

# %% [markdown]
# ## Train Random Forrest

# %%
# RF_classifier = RandomForestClassifier(criterion='entropy', min_samples_leaf=1,
#                                        min_samples_split=2, n_estimators=2500)
RF_classifier = RandomForestClassifier(criterion='entropy')
RF_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy')

# %% [markdown]
# ### Cross Validation & KFold

# %%
num_folds = 5
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)
cross_val_results = cross_val_score(RF_classifier, X_test, y_test, cv=kf, scoring='accuracy')
print("Cross-Validation Accuracy Scores:", cross_val_results)
print("Mean Accuracy:", cross_val_results.mean())
# Out:
# Cross-Validation Accuracy Scores: [0.99015748 0.99015748 0.98818898 0.98818898 0.98816568]
# Mean Accuracy: 0.98897171877184

# %% [markdown]
# ## Measure Random Forrest's performance

# %%
# Predict the class labels of samples in the test dataset
y_pred_RF = RF_classifier.predict(X_test)

# %%
score_test = accuracy_score(y_test, y_pred_RF)
print (score_test)
# Out:
# 0.9948798739661284

# %%
precision_test = precision_score(y_test, y_pred_RF, average='macro')
print (precision_test)
# Out:
# 0.9950973946691211

# %%
recall_test = recall_score(y_test, y_pred_RF, average='macro')
print (recall_test)
# Out:
# 0.9945901417859475

# %%
f1_test =  f1_score(y_test, y_pred_RF, average='macro')
print(f1_test)
# Out:
# 0.9948360116493644

# %%
mat = confusion_matrix(y_test, y_pred_RF)
class_names = ["Not Expired", "Expired"]
plt.figure(figsize=(8, 6))
sns.heatmap(mat, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix (Random Forest)")
plt.show()

# %%
report = classification_report(y_test, y_pred_RF)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      1383
#            1       1.00      0.99      0.99      1156
#
#     accuracy                           0.99      2539
#    macro avg       1.00      0.99      0.99      2539
# weighted avg       0.99      0.99      0.99      2539

# %% [markdown]
# ## ROC Curve

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Get the probabilities of each class.
y_probs = RF_classifier.predict_proba(X_test)

# The 'positive' class value is 1, so we want the probabilities of the class being 1.
# i.e., the second column of the array.
y_probs_class_1 = y_probs[:,1]

auc = roc_auc_score(y_test, y_probs_class_1)
print('The AUC is {:.3f}'.format(auc)) # uses string formatting to get 3 decimal places.

fpr, tpr, thresholds = roc_curve(y_test, y_probs_class_1, pos_label=1)

print("Threshold\tTPR vs FPR")
for f, p, t in zip(fpr, tpr, thresholds):
    print("{:.3f}\t{:.3f} vs {:.3f}".format(t, p, f))

# Here is some code to plot the ROC curve.
# Follows the example at https://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html#sphx-glr-auto-examples-model-selection-plot-roc-py

import matplotlib.pyplot as plt
plt.figure()
lw = 2 # the line width
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--') # The dashed line for random choice
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (Random Forest)')
plt.legend(loc="lower right")
plt.show()
# Out:
# The AUC is 1.000
# Threshold	TPR vs FPR
# 2.000	0.000 vs 0.000
# 1.000	0.935 vs 0.000
# 0.990	0.954 vs 0.000
# 0.980	0.964 vs 0.000
# 0.970	0.971 vs 0.000
# 0.960	0.973 vs 0.000
# 0.930	0.978 vs 0.000
# 0.920	0.981 vs 0.000
# 0.890	0.982 vs 0.000
# 0.880	0.984 vs 0.000
# 0.870	0.984 vs 0.001
# 0.780	0.987 vs 0.001
# 0.760	0.988 vs 0.001
# 0.560	0.991 vs 0.001
# 0.440	0.991 vs 0.004
# 0.400	0.992 vs 0.004
# 0.390	0.992 vs 0.006
# 0.320	0.992 vs 0.009
# 0.300	0.993 vs 0.009
# 0.290	0.993 vs 0.009
# 0.270	0.995 vs 0.011
# 0.250	0.995 vs 0.012
# 0.230	0.995 vs 0.013
# 0.220	0.996 vs 0.013
# 0.200	0.997 vs 0.014
# 0.190	0.997 vs 0.015
# 0.180	0.997 vs 0.017
# 0.160	0.997 vs 0.017
# 0.130	0.997 vs 0.019
# 0.120	0.997 vs 0.020
# 0.110	0.998 vs 0.025
# 0.100	0.999 vs 0.027
# 0.090	0.999 vs 0.033
# 0.080	0.999 vs 0.035
# 0.070	0.999 vs 0.038
# 0.060	0.999 vs 0.043
# 0.050	0.999 vs 0.048
# 0.040	0.999 vs 0.059
# 0.030	1.000 vs 0.076
# 0.020	1.000 vs 0.100
# 0.010	1.000 vs 0.157
# 0.000	1.000 vs 1.000

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Get the probabilities of each class.
y_probs = RF_classifier.predict_proba(X_test)

# Initialize lists to store TPR and FPR for each class
tpr_list = []
fpr_list = []

# Convert multi-class labels to binary labels for each class and calculate ROC curves
for pos in range(2):
    binary_labels = (y_test == pos).astype(int)
    fpr, tpr, thresholds = roc_curve(binary_labels, y_probs[:, pos], pos_label=1)
    auc = roc_auc_score(binary_labels, y_probs[:, pos])

    # Store TPR and FPR for plotting
    tpr_list.append(tpr)
    fpr_list.append(fpr)

# Plot ROC curves for all classes on the same graph
plt.figure()
lw = 2
colors = ['darkorange', 'green']
labels = ['Class 0', 'Class 1']

for i in range(len(tpr_list)):
    plt.plot(fpr_list[i], tpr_list[i], color=colors[i], lw=lw, label='ROC curve - %s' % (labels[i]))

plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (RF)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Measuring performance on small unseen set

# %%
solution_validate = RF_classifier.predict(futureSample_X)

# %%
score_validate = accuracy_score(futureSample_y, solution_validate)
print (score_validate)
# Out:
# 0.998

# %% [markdown]
# # Support Vector Machine

# %% [markdown]
# ## Optimize parameters - too computationally expensive

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.svm import SVC
from scipy.stats import uniform

param_dist = {
    'C': uniform(0.1, 10),  # Example range for C (adjust based on your dataset)
    'kernel': ['linear', 'poly', 'rbf'],
    'degree': [2, 3, 4],
    'gamma': ['scale', 'auto', 0.1, 1],
    'class_weight': [None, 'balanced']
}

randomized_search = RandomizedSearchCV(
    estimator=SVC(probability=True),
    param_distributions=param_dist,
    n_iter=3,  # Number of parameter settings that are sampled
    cv=5,       # Number of cross-validation folds
    n_jobs=-1,   # Use all available CPU cores for parallelism
    random_state=42
)

randomized_search.fit(X_train_resampled, y_train_resampled)
best_params = randomized_search.best_params_
best_classifier = randomized_search.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-a45498603f0a> in <cell line: 22>()
#      20 )
#      21
# ---> 22 randomized_search.fit(X_train_resampled, y_train_resampled)
#      23 best_params = randomized_search.best_params_
#      24 best_classifier = randomized_search.best_estimator_
#
# NameError: name 'X_train_resampled' is not defined

# %% [markdown]
# ## Train SVM

# %%
SVM_classifier = SVC(probability=True)
SVM_classifier.fit(X_train_resampled, y_train_resampled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-2cf01be90c90> in <cell line: 2>()
#       1 SVM_classifier = SVC(probability=True)
# ----> 2 SVM_classifier.fit(X_train_resampled, y_train_resampled)
#
# NameError: name 'X_train_resampled' is not defined

# %% [markdown]
# ## Measure SVM's performance

# %%
# Predict the class labels of samples in the test dataset
y_pred_SVM = SVM_classifier.predict(X_test)

# %%
score_test = accuracy_score(y_test, y_pred_SVM)
print (score_test)

# %%
precision_test = precision_score(y_test, y_pred_SVM, average='macro')
print (precision_test)

# %%
recall_test = recall_score(y_test, y_pred_SVM, average='macro')
print (recall_test)

# %%
f1_test =  f1_score(y_test, y_pred_SVM, average='macro')
print(f1_test)

# %%
mat = confusion_matrix(y_test, y_pred_SVM)
class_names = ["Not Expired", "Expired"]
plt.figure(figsize=(8, 6))
sns.heatmap(mat, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix (SVM)")
plt.show()

# %%
report = classification_report(y_test, y_pred_SVM)
print(report)

# %% [markdown]
# ## ROC Curve

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Get the probabilities of each class.
y_probs = SVM_classifier.predict_proba(X_test)

# The 'positive' class value is 1, so we want the probabilities of the class being 1.
# i.e., the second column of the array.
y_probs_class_1 = y_probs[:,1]

auc = roc_auc_score(y_test, y_probs_class_1)
print('The AUC is {:.3f}'.format(auc)) # uses string formatting to get 3 decimal places.

fpr, tpr, thresholds = roc_curve(y_test, y_probs_class_1, pos_label=1)

print("Threshold\tTPR vs FPR")
for f, p, t in zip(fpr, tpr, thresholds):
    print("{:.3f}\t{:.3f} vs {:.3f}".format(t, p, f))

# Here is some code to plot the ROC curve.
# Follows the example at https://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html#sphx-glr-auto-examples-model-selection-plot-roc-py

import matplotlib.pyplot as plt
plt.figure()
lw = 2 # the line width
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--') # The dashed line for random choice
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (SVM)')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Get the probabilities of each class.
y_probs = SVM_classifier.predict_proba(X_test)

# Initialize lists to store TPR and FPR for each class
tpr_list = []
fpr_list = []

# Convert multi-class labels to binary labels for each class and calculate ROC curves
for pos in range(2):
    binary_labels = (y_test == pos).astype(int)
    fpr, tpr, thresholds = roc_curve(binary_labels, y_probs[:, pos], pos_label=1)
    auc = roc_auc_score(binary_labels, y_probs[:, pos])

    # Store TPR and FPR for plotting
    tpr_list.append(tpr)
    fpr_list.append(fpr)

# Plot ROC curves for all classes on the same graph
plt.figure()
lw = 2
colors = ['darkorange', 'green']
labels = ['Class 0', 'Class 1']

for i in range(len(tpr_list)):
    plt.plot(fpr_list[i], tpr_list[i], color=colors[i], lw=lw, label='ROC curve - %s' % (labels[i]))

plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (SVM)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Measuring performance on small unseen set

# %%
solution_validate = SVM_classifier.predict(future_sample_X)

# %%
score_validate = accuracy_score(future_sample_y, solution_validate)
print (score_validate)

# %% [markdown]
# # Neural Network

# %%
import tensorflow as tf
from keras.layers import Dense, Dropout
from tensorflow.keras.models import load_model

input_dim   = X_train.shape[1]

# %%
class CustomCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        print("Epoch {}: Loss - {:.4f}, Accuracy - {:.4f}".format(epoch+1, logs['loss'], logs['accuracy']))

# %% [markdown]
# ## Hyper Parameter Tuning

# %%
import kerastuner
from kerastuner.tuners import RandomSearch

epochNo = 10
batchSize = 100

def build_model(hp):
    model = tf.keras.Sequential()
    model.add(tf.keras.Input(shape=(input_dim)))
    model.add(Dense(units=hp.Int('units1', min_value=2048, max_value=4196, step=256), activation='relu'))
    model.add(Dropout(rate=hp.Float('dropout_rate1', min_value=0.2, max_value=0.5, step=0.1)))
    model.add(Dense(units=hp.Int('units2', min_value=1024, max_value=2048, step=128), activation='relu'))
    model.add(Dropout(rate=hp.Float('dropout_rate2', min_value=0.2, max_value=0.5, step=0.1)))
    model.add(Dense(units=hp.Int('units3', min_value=512, max_value=1024, step=64), activation='relu'))
    model.add(Dropout(rate=hp.Float('dropout_rate3', min_value=0.2, max_value=0.5, step=0.1)))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,  # Number of hyperparameter combinations to try
    directory='my_dir',  # Directory to save optimization logs and checkpoints
    project_name='opt_2'
)

tuner.search(X_train_resampled, y_train_resampled, epochs=epochNo, batch_size=batchSize, validation_data=(X_test, y_test))

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
best_hyperparameters_list = best_hps.values
print("Best Hyperparameters:", best_hyperparameters_list)
# Out:
# Best Hyperparameters: {'units1': 1792, 'dropout_rate1': 0.2, 'units2': 896, 'dropout_rate2': 0.2, 'units3': 320, 'dropout_rate3': 0.30000000000000004}

# %%
predictions = model.predict(X_test)
y_preds_FNN = (predictions > 0.5)*1
# Out:
# 294/294 [==============================] - 1s 3ms/step

# %% [markdown]
# ## Using a FNN

# %%
n_neurons_1   = 3328
n_neurons_2   = 2048
n_neurons_3   = 960
epochNo      =  100
batchSize = 100

model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=(input_dim))) # tf.keras.Input() is used to instantiate a Keras tensor.
model.add(Dense(n_neurons_1, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(n_neurons_2, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(n_neurons_3, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation=tf.keras.activations.sigmoid))

callbacks = [CustomCallback()]

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train_resampled, y_train_resampled, epochs=epochNo, batch_size=batchSize, verbose=3, callbacks=callbacks)

predictions = model.predict(X_test)
y_preds_FNN = (predictions > 0.5)*1
scores = model.evaluate(X_test, y_test)
print('The evaluation scores are {}'.format(scores))
model.save("model.h5")
loaded_model = load_model ('model.h5')
loaded_model.summary()

# %% [markdown]
# ## Measuring the perfomance of the FNN

# %%
loaded_model = load_model ('model.h5')
predictions = loaded_model.predict(X_test)
y_preds_FNN = (predictions > 0.5)*1
# Out:
# 294/294 [==============================] - 16s 53ms/step

# %%
score_test = accuracy_score(y_test, y_preds_FNN)
print (score_test)
# Out:
# 0.9284040059663329

# %%
precision_test = precision_score(y_test, y_preds_FNN, average='macro')
print (precision_test)
# Out:
# 0.816721182997243

# %%
recall_test = recall_score(y_test, y_preds_FNN, average='macro')
print (recall_test)
# Out:
# 0.7515259392367567

# %%
f1_test =  f1_score(y_test, y_preds_FNN, average='macro')
print(f1_test)
# Out:
# 0.7791555702768245

# %%
mat = confusion_matrix(y_test, y_preds_FNN)
class_names = ["Not Expired", "Expired"]
plt.figure(figsize=(8, 6))
sns.heatmap(mat, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix (FNN)")
plt.show()

# %%
report = classification_report(y_test, y_preds_FNN)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96      8445
#            1       0.68      0.53      0.60       941
#
#     accuracy                           0.93      9386
#    macro avg       0.82      0.75      0.78      9386
# weighted avg       0.92      0.93      0.92      9386

# %% [markdown]
# ## ROC Curve

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Get the probabilities of the positive class (class 1) using the predict method.
y_probs = predictions
# The predicted probabilities for class 1 are already in y_probs.
# Calculate ROC curve and AUC.
fpr, tpr, thresholds = roc_curve(y_test, y_probs)
auc = roc_auc_score(y_test, y_probs)

print('The AUC is {:.3f}'.format(auc))

# Plot ROC curve.
plt.figure()
lw = 2  # line width
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = {:.2f})'.format(auc))
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (FNN)')
plt.legend(loc='lower right')
plt.show()
# Out:
# The AUC is 0.914

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Get probabilities from the model
predictions = loaded_model.predict(X_test)

# Ensure predictions is a 2D array with shape (n_samples, n_classes)
if predictions.shape[1] == 1:
    # If predictions have only one column, assume binary classification and create a 2D array
    positive_probs = predictions[:, 0]  # Probabilities for the positive class
    negative_probs = 1 - positive_probs  # Probabilities for the negative class
else:
    # If predictions already have multiple columns, assume they represent probabilities for each class
    positive_probs = predictions[:, 1]  # Probabilities for the positive class
    negative_probs = predictions[:, 0]  # Probabilities for the negative class

# Calculate ROC curve and AUC score for positive class
fpr_positive, tpr_positive, _ = roc_curve(y_test, positive_probs, pos_label=1)
auc_positive = roc_auc_score(y_test, positive_probs)

# Calculate ROC curve and AUC score for negative class
fpr_negative, tpr_negative, _ = roc_curve(y_test, negative_probs, pos_label=0)
auc_negative = roc_auc_score(y_test, negative_probs)

# Plot ROC curves for both positive and negative classes on the same graph
plt.figure()
lw = 2
plt.plot(fpr_positive, tpr_positive, color='darkorange', lw=lw, label='Class 0')
plt.plot(fpr_negative, tpr_negative, color='green', lw=lw, label='Class 1')
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# 294/294 [==============================] - 7s 24ms/step

# %% [markdown]
# ## Measuring performance on small unseen set

# %%
predictions_val = loaded_model.predict(future_sample_X)
y_preds_val = (predictions_val > 0.5)*1     # threshold is 0.5
loss, accuracy = model.evaluate(future_sample_X, future_sample_y)
print('Loss: %.4f, Accuracy: %.2f%%' % (loss, accuracy*100))
# Out:
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1544 - accuracy: 0.9600
# Loss: 0.1544, Accuracy: 96.00%

# %% [markdown]
# # Naive Bayes - Gaussian

# %% [markdown]
# ## Hyper parameter optimisation

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV

# Define the parameter grid to search
param_grid = {
    'var_smoothing': [1e-9, 1e-8, 1e-7, 1e-6, 1e-5]
}

# Create a Gaussian Naive Bayes classifier
GNB_classifier = GaussianNB()

# Instantiate GridSearchCV with the classifier, parameter grid, and cross-validation strategy
grid_search = GridSearchCV(estimator=GNB_classifier, param_grid=param_grid, cv=5, n_jobs=-1)

# Perform the grid search on the training data
grid_search.fit(X_train_resampled, y_train_resampled)

# Print the best hyperparameters and corresponding accuracy score
print("Best Hyperparameters: ", grid_search.best_params_)
print("Best Accuracy Score: ", grid_search.best_score_)
# Out:
# Best Hyperparameters:  {'var_smoothing': 1e-09}
# Best Accuracy Score:  0.7224971212233731

# %% [markdown]
# ## Train Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
GNB_classifier = GaussianNB()
GNB_classifier.fit(X_train_resampled, y_train_resampled)
# Out:
# GaussianNB()

# %%
# Predict the class labels of samples in the test dataset
y_pred_GNB = GNB_classifier.predict(X_test)

# %%
score_test = accuracy_score(y_test, y_pred_GNB)
print (score_test)
# Out:
# 0.8992115917323673

# %%
precision_test = precision_score(y_test, y_pred_GNB, average='macro')
print (precision_test)
# Out:
# 0.720279416177506

# %%
recall_test = recall_score(y_test, y_pred_GNB, average='macro')
print (recall_test)
# Out:
# 0.7173618884209825

# %%
f1_test =  f1_score(y_test, y_pred_GNB, average='macro')
print(f1_test)
# Out:
# 0.7188064657352111

# %%
mat = confusion_matrix(y_test, y_pred_GNB)
class_names = ["Not Expired", "Expired"]
plt.figure(figsize=(8, 6))
sns.heatmap(mat, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix (GNB)")
plt.show()

# %%
report = classification_report(y_test, y_pred_GNB)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      8445
#            1       0.50      0.49      0.49       941
#
#     accuracy                           0.90      9386
#    macro avg       0.72      0.72      0.72      9386
# weighted avg       0.90      0.90      0.90      9386

# %% [markdown]
# ## ROC Curve

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Get the probabilities of each class.
y_probs = GNB_classifier.predict_proba(X_test)

# The 'positive' class value is 1, so we want the probabilities of the class being 1.
# i.e., the second column of the array.
y_probs_class_1 = y_probs[:,1]

auc = roc_auc_score(y_test, y_probs_class_1)
print('The AUC is {:.3f}'.format(auc)) # uses string formatting to get 3 decimal places.

fpr, tpr, thresholds = roc_curve(y_test, y_probs_class_1, pos_label=1)

print("Threshold\tTPR vs FPR")
for f, p, t in zip(fpr, tpr, thresholds):
    print("{:.3f}\t{:.3f} vs {:.3f}".format(t, p, f))

# Here is some code to plot the ROC curve.
# Follows the example at https://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html#sphx-glr-auto-examples-model-selection-plot-roc-py

import matplotlib.pyplot as plt
plt.figure()
lw = 2 # the line width
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--') # The dashed line for random choice
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic


# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Get the probabilities of each class.
y_probs = GNB_classifier.predict_proba(X_test)

# Initialize lists to store TPR and FPR for each class
tpr_list = []
fpr_list = []

# Convert multi-class labels to binary labels for each class and calculate ROC curves
for pos in range(2):
    binary_labels = (y_test == pos).astype(int)
    fpr, tpr, thresholds = roc_curve(binary_labels, y_probs[:, pos], pos_label=1)
    auc = roc_auc_score(binary_labels, y_probs[:, pos])

    # Store TPR and FPR for plotting
    tpr_list.append(tpr)
    fpr_list.append(fpr)

# Plot ROC curves for all classes on the same graph
plt.figure()
lw = 2
colors = ['darkorange', 'green']
labels = ['Class 0', 'Class 1']

for i in range(len(tpr_list)):
    plt.plot(fpr_list[i], tpr_list[i], color=colors[i], lw=lw, label='ROC curve - %s' % (labels[i]))

plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (GNB)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Measuring performance on small unseen set

# %%
solution_validate = GNB_classifier.predict(future_sample_X)

# %%
score_validate = accuracy_score(future_sample_y, solution_validate)
print (score_validate)
# Out:
# 0.88

# %% [markdown]
# # Quadratic Discrimination Analysis

# %% [markdown]
# ## Hyper parameter optimisation

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# Define the parameter grid to search
param_grid = {
    'reg_param': [0.1, 0.01, 0.001, 0.0001]  # Regularization parameter to avoid singular matrices
}

# Create a Quadratic Discriminant Analysis classifier
QDA_classifier = QuadraticDiscriminantAnalysis()

# Instantiate GridSearchCV with the classifier, parameter grid, and cross-validation strategy
grid_search = GridSearchCV(estimator=QDA_classifier, param_grid=param_grid, cv=5, n_jobs=-1)

# Perform the grid search on the training data
grid_search.fit(X_train_resampled, y_train_resampled)

# Print the best hyperparameters and corresponding accuracy score
print("Best Hyperparameters: ", grid_search.best_params_)
print("Best Accuracy Score: ", grid_search.best_score_)
# Out:
# Best Hyperparameters:  {'reg_param': 0.1}
# Best Accuracy Score:  0.7033173422035229

# %% [markdown]
# ## Train QDA

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
QDA_classifier = QuadraticDiscriminantAnalysis(reg_param = 0.1)
QDA_classifier.fit(X_train_resampled, y_train_resampled)
# Out:
# QuadraticDiscriminantAnalysis(reg_param=0.1)

# %%
# Predict the class labels of samples in the test dataset
y_pred_QDA = QDA_classifier.predict(X_test)

# %%
score_test = accuracy_score(y_test, y_pred_QDA)
print (score_test)
# Out:
# 0.8964415086298743

# %%
precision_test = precision_score(y_test, y_pred_QDA, average='macro')
print (precision_test)
# Out:
# 0.7117229869041035

# %%
recall_test = recall_score(y_test, y_pred_QDA, average='macro')
print (recall_test)
# Out:
# 0.7044910840853708

# %%
f1_test =  f1_score(y_test, y_pred_QDA, average='macro')
print(f1_test)
# Out:
# 0.7080148384101133

# %%
mat = confusion_matrix(y_test, y_pred_QDA)
class_names = ["Not Expired", "Expired"]
plt.figure(figsize=(8, 6))
sns.heatmap(mat, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix (QDA)")
plt.show()

# %%
report = classification_report(y_test, y_pred_QDA)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      8445
#            1       0.48      0.46      0.47       941
#
#     accuracy                           0.90      9386
#    macro avg       0.71      0.70      0.71      9386
# weighted avg       0.89      0.90      0.90      9386

# %% [markdown]
# ## ROC Curve

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Get the probabilities of each class.
y_probs = QDA_classifier.predict_proba(X_test)

# The 'positive' class value is 1, so we want the probabilities of the class being 1.
# i.e., the second column of the array.
y_probs_class_1 = y_probs[:,1]

auc = roc_auc_score(y_test, y_probs_class_1)
print('The AUC is {:.3f}'.format(auc)) # uses string formatting to get 3 decimal places.

fpr, tpr, thresholds = roc_curve(y_test, y_probs_class_1, pos_label=1)

print("Threshold\tTPR vs FPR")
for f, p, t in zip(fpr, tpr, thresholds):
    print("{:.3f}\t{:.3f} vs {:.3f}".format(t, p, f))

# Here is some code to plot the ROC curve.
# Follows the example at https://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html#sphx-glr-auto-examples-model-selection-plot-roc-py

import matplotlib.pyplot as plt
plt.figure()
lw = 2 # the line width
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--') # The dashed line for random choice
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (QDA)')
plt.legend(loc="lower right")
plt.show()
# Out:
# The AUC is 0.842
# Threshold	TPR vs FPR
# 2.000	0.000 vs 0.000
# 1.000	0.166 vs 0.008
# 1.000	0.167 vs 0.008
# 1.000	0.169 vs 0.008
# 1.000	0.169 vs 0.008
# 1.000	0.173 vs 0.008
# 1.000	0.174 vs 0.008
# 1.000	0.174 vs 0.009
# 1.000	0.175 vs 0.009
# 1.000	0.175 vs 0.009
# 1.000	0.182 vs 0.009
# 1.000	0.182 vs 0.009
# 1.000	0.189 vs 0.009
# 1.000	0.189 vs 0.009
# 1.000	0.190 vs 0.009
# 1.000	0.190 vs 0.009
# 1.000	0.193 vs 0.009
# 1.000	0.193 vs 0.009
# 1.000	0.199 vs 0.009
# 1.000	0.199 vs 0.009
# 1.000	0.202 vs 0.009
# 1.000	0.202 vs 0.010
# 1.000	0.203 vs 0.010
# 1.000	0.203 vs 0.010
# 1.000	0.205 vs 0.010
# 1.000	0.205 vs 0.010
# 1.000	0.206 vs 0.010
# 1.000	0.206 vs 0.011
# 1.000	0.208 vs 0.011
# 1.000	0.208 vs 0.011
# 1.000	0.213 vs 0.011
# 1.000	0.213 vs 0.011
# 1.000	0.217 vs 0.011
# 1.000	0.217 vs 0.011
# 1.000	0.218 vs 0.011
# 1.000	0.218 vs 0.011
# 1.000	0.220 vs 0.011
# 1.000	0.220 vs 0.012
# 1.000	0.221 vs 0.012
# 1.000	0.221 vs 0.012
# 1.000	0.222 vs 0.012
# 1.000	0.222 vs 0.012
# 1.000	0.223 vs 0.012
# 1.000	0.223 vs 0.012
# 1.000	0.225 vs 0.012
# 1.000	0.225 vs 0.013
# 1.000	0.226 vs 0.013
# 1.000	0.226 vs 0.013
# 1.000	0.230 vs 0.013
# 1.000	0.230 vs 0.013
# 1.000	0.231 vs 0.013
# 1.000	0.231 vs 0.013
# 1.000	0.232 vs 0.013
# 1.000	0.232 vs 0.014
# 1.000	0.234 vs 0.014
# 1.000	0.234 vs 0.014
# 1.000	0.235 vs 0.014
# 1.000	0.235 vs 0.014
# 1.000	0.238 vs 0.014
# 1.000	0.238 vs 0.014
# 1.000	0.240 vs 0.014
# 1.000	0.240 vs 0.015
# 1.000	0.241 vs 0.015
# 1.000	0.241 vs 0.015
# 1.000	0.243 vs 0.015
# 1.000	0.243 vs 0.015
# 1.000	0.245 vs 0.015
# 1.000	0.245 vs 0.015
# 1.000	0.247 vs 0.015
# 1.000	0.247 vs 0.015
# 1.000	0.248 vs 0.015
# 0.999	0.325 vs 0.029
# 0.999	0.327 vs 0.029
# 0.999	0.327 vs 0.030
# 0.998	0.333 vs 0.030
# 0.998	0.333 vs 0.030
# 0.998	0.336 vs 0.030
# 0.998	0.336 vs 0.030
# 0.998	0.337 vs 0.030
# 0.997	0.337 vs 0.032
# 0.997	0.338 vs 0.032
# 0.997	0.338 vs 0.032
# 0.997	0.339 vs 0.032
# 0.997	0.339 vs 0.032
# 0.996	0.340 vs 0.032
# 0.996	0.340 vs 0.032
# 0.996	0.341 vs 0.032
# 0.996	0.341 vs 0.033
# 0.996	0.343 vs 0.033
# 0.996	0.343 vs 0.033
# 0.995	0.345 vs 0.033
# 0.995	0.345 vs 0.033
# 0.995	0.346 vs 0.033
# 0.995	0.346 vs 0.034
# 0.995	0.348 vs 0.034
# 0.994	0.348 vs 0.034
# 0.994	0.349 vs 0.034
# 0.994	0.349 vs 0.034
# 0.994	0.350 vs 0.034
# 0.993	0.350 vs 0.034
# 0.993	0.351 vs 0.034
# 0.992	0.351 vs 0.035
# 0.992	0.352 vs 0.035
# 0.992	0.352 vs 0.035
# 0.991	0.353 vs 0.035
# 0.990	0.353 vs 0.036
# 0.990	0.354 vs 0.036
# 0.990	0.354 vs 0.036
# 0.989	0.356 vs 0.036
# 0.989	0.356 vs 0.036
# 0.989	0.358 vs 0.036
# 0.987	0.358 vs 0.036
# 0.986	0.360 vs 0.036
# 0.986	0.360 vs 0.036
# 0.985	0.361 vs 0.036
# 0.985	0.361 vs 0.037
# 0.985	0.363 vs 0.037
# 0.984	0.363 vs 0.037
# 0.984	0.365 vs 0.037
# 0.981	0.365 vs 0.038
# 0.981	0.367 vs 0.038
# 0.979	0.367 vs 0.038
# 0.978	0.368 vs 0.038
# 0.972	0.368 vs 0.039
# 0.971	0.370 vs 0.039
# 0.971	0.370 vs 0.039
# 0.971	0.371 vs 0.039
# 0.971	0.371 vs 0.039
# 0.970	0.373 vs 0.039
# 0.969	0.373 vs 0.039
# 0.968	0.375 vs 0.039
# 0.967	0.375 vs 0.039
# 0.966	0.376 vs 0.039
# 0.966	0.376 vs 0.040
# 0.965	0.377 vs 0.040
# 0.962	0.377 vs 0.040
# 0.960	0.378 vs 0.040
# 0.960	0.378 vs 0.040
# 0.959	0.379 vs 0.040
# 0.959	0.379 vs 0.040
# 0.956	0.383 vs 0.040
# 0.954	0.383 vs 0.040
# 0.953	0.384 vs 0.040
# 0.952	0.384 vs 0.041
# 0.950	0.385 vs 0.041
# 0.950	0.385 vs 0.041
# 0.950	0.386 vs 0.041
# 0.949	0.386 vs 0.041
# 0.948	0.388 vs 0.041
# 0.947	0.388 vs 0.042
# 0.937	0.391 vs 0.042
# 0.935	0.391 vs 0.042
# 0.934	0.393 vs 0.042
# 0.931	0.393 vs 0.042
# 0.930	0.394 vs 0.042
# 0.930	0.394 vs 0.042
# 0.926	0.400 vs 0.042
# 0.926	0.400 vs 0.042
# 0.925	0.401 vs 0.042
# 0.920	0.401 vs 0.043
# 0.918	0.403 vs 0.043
# 0.014	0.672 vs 0.125
# 0.013	0.672 vs 0.128
# 0.013	0.673 vs 0.128
# 0.013	0.673 vs 0.128
# 0.013	0.674 vs 0.128
# 0.013	0.674 vs 0.128
# 0.013	0.675 vs 0.128
# 0.013	0.675 vs 0.129
# 0.012	0.676 vs 0.129
# 0.012	0.676 vs 0.129
# 0.012	0.677 vs 0.129
# 0.012	0.677 vs 0.130
# 0.012	0.678 vs 0.130
# 0.012	0.678 vs 0.130
# 0.012	0.679 vs 0.130
# 0.012	0.679 vs 0.130
# 0.012	0.680 vs 0.130
# 0.012	0.680 vs 0.131
# 0.012	0.681 vs 0.131
# 0.011	0.681 vs 0.132
# 0.011	0.684 vs 0.132
# 0.011	0.685 vs 0.132
# 0.011	0.685 vs 0.132
# 0.011	0.688 vs 0.132
# 0.011	0.688 vs 0.133
# 0.011	0.689 vs 0.133
# 0.011	0.689 vs 0.133
# 0.011	0.690 vs 0.133
# 0.011	0.690 vs 0.133
# 0.011	0.691 vs 0.133
# 0.011	0.691 vs 0.134
# 0.011	0.692 vs 0.134
# 0.011	0.692 vs 0.135
# 0.011	0.693 vs 0.135
# 0.010	0.693 vs 0.135
# 0.010	0.696 vs 0.135
# 0.010	0.696 vs 0.137
# 0.010	0.697 vs 0.137
# 0.010	0.697 vs 0.139
# 0.010	0.698 vs 0.139
# 0.010	0.698 vs 0.139
# 0.009	0.699 vs 0.139
# 0.009	0.699 vs 0.139
# 0.009	0.700 vs 0.139
# 0.009	0.700 vs 0.141
# 0.009	0.702 vs 0.141
# 0.009	0.702 vs 0.141
# 0.009	0.704 vs 0.141
# 0.009	0.704 vs 0.142
# 0.009	0.707 vs 0.142
# 0.009	0.707 vs 0.143
# 0.009	0.708 vs 0.143
# 0.009	0.708 vs 0.143
# 0.009	0.709 vs 0.143
# 0.009	0.709 vs 0.143
# 0.009	0.710 vs 0.143
# 0.008	0.710 vs 0.145
# 0.008	0.711 vs 0.145
# 0.008	0.711 vs 0.146
# 0.008	0.712 vs 0.146
# 0.008	0.712 vs 0.147
# 0.008	0.714 vs 0.147
# 0.008	0.714 vs 0.148
# 0.008	0.715 vs 0.148
# 0.008	0.715 vs 0.148
# 0.008	0.716 vs 0.148
# 0.007	0.716 vs 0.151
# 0.007	0.717 vs 0.151
# 0.007	0.717 vs 0.152
# 0.007	0.718 vs 0.152
# 0.007	0.718 vs 0.152
# 0.007	0.719 vs 0.152
# 0.007	0.719 vs 0.153
# 0.007	0.721 vs 0.153
# 0.007	0.721 vs 0.155
# 0.007	0.722 vs 0.155
# 0.007	0.722 vs 0.156
# 0.007	0.723 vs 0.156
# 0.007	0.723 vs 0.156
# 0.007	0.724 vs 0.156
# 0.007	0.724 vs 0.158
# 0.007	0.725 vs 0.158
# 0.006	0.725 vs 0.159
# 0.006	0.726 vs 0.159
# 0.006	0.726 vs 0.159
# 0.006	0.727 vs 0.159
# 0.006	0.727 vs 0.160
# 0.006	0.728 vs 0.160
# 0.006	0.728 vs 0.161
# 0.006	0.729 vs 0.161
# 0.001	0.831 vs 0.337
# 0.001	0.831 vs 0.340
# 0.001	0.832 vs 0.340
# 0.001	0.832 vs 0.344
# 0.001	0.833 vs 0.344
# 0.001	0.833 vs 0.344
# 0.001	0.834 vs 0.344
# 0.001	0.834 vs 0.345
# 0.001	0.835 vs 0.345
# 0.001	0.835 vs 0.346
# 0.001	0.836 vs 0.346
# 0.001	0.836 vs 0.348
# 0.001	0.837 vs 0.348
# 0.001	0.837 vs 0.350
# 0.001	0.838 vs 0.350
# 0.001	0.838 vs 0.350
# 0.001	0.840 vs 0.350
# 0.001	0.840 vs 0.351
# 0.001	0.841 vs 0.351
# 0.001	0.841 vs 0.355
# 0.001	0.842 vs 0.355
# 0.001	0.842 vs 0.355
# 0.001	0.843 vs 0.355
# 0.001	0.843 vs 0.357
# 0.001	0.844 vs 0.357
# 0.001	0.844 vs 0.358
# 0.001	0.845 vs 0.358
# 0.001	0.845 vs 0.363
# 0.001	0.846 vs 0.363
# 0.001	0.846 vs 0.363
# 0.001	0.847 vs 0.363
# 0.001	0.847 vs 0.366
# 0.001	0.848 vs 0.366
# 0.001	0.848 vs 0.370
# 0.001	0.849 vs 0.370
# 0.001	0.849 vs 0.370
# 0.001	0.850 vs 0.370
# 0.001	0.850 vs 0.370
# 0.001	0.851 vs 0.370
# 0.001	0.851 vs 0.371
# 0.001	0.852 vs 0.371
# 0.001	0.852 vs 0.373
# 0.001	0.853 vs 0.373
# 0.001	0.853 vs 0.373
# 0.001	0.854 vs 0.373
# 0.001	0.854 vs 0.376
# 0.001	0.855 vs 0.376
# 0.001	0.855 vs 0.378
# 0.001	0.857 vs 0.378
# 0.001	0.857 vs 0.382
# 0.001	0.858 vs 0.382
# 0.001	0.858 vs 0.385
# 0.001	0.859 vs 0.385
# 0.001	0.859 vs 0.388
# 0.001	0.860 vs 0.388
# 0.001	0.860 vs 0.388
# 0.001	0.861 vs 0.388
# 0.001	0.861 vs 0.388
# 0.001	0.862 vs 0.388
# 0.001	0.862 vs 0.397
# 0.001	0.863 vs 0.397
# 0.001	0.863 vs 0.403
# 0.001	0.864 vs 0.403
# 0.001	0.864 vs 0.406
# 0.001	0.865 vs 0.406
# 0.001	0.865 vs 0.409
# 0.001	0.866 vs 0.409
# 0.001	0.866 vs 0.413
# 0.001	0.867 vs 0.413
# 0.001	0.867 vs 0.414
# 0.001	0.868 vs 0.414
# 0.001	0.868 vs 0.415
# 0.001	0.869 vs 0.415
# 0.001	0.869 vs 0.419
# 0.001	0.870 vs 0.419
# 0.001	0.870 vs 0.430
# 0.001	0.871 vs 0.430
# 0.001	0.871 vs 0.434
# 0.001	0.872 vs 0.434
# 0.001	0.872 vs 0.448
# 0.001	0.874 vs 0.448
# 0.001	0.874 vs 0.452
# 0.001	0.875 vs 0.452
# 0.001	0.875 vs 0.455
# 0.001	0.876 vs 0.455
# 0.001	0.876 vs 0.455
# 0.001	0.877 vs 0.455
# 0.001	0.877 vs 0.461
# 0.001	0.878 vs 0.461
# 0.001	0.878 vs 0.461
# 0.000	0.977 vs 0.788
# 0.000	0.977 vs 0.811
# 0.000	0.978 vs 0.811
# 0.000	0.978 vs 0.813
# 0.000	0.979 vs 0.813
# 0.000	0.979 vs 0.821
# 0.000	0.980 vs 0.821
# 0.000	0.980 vs 0.823
# 0.000	0.981 vs 0.823
# 0.000	0.981 vs 0.824
# 0.000	0.982 vs 0.824
# 0.000	0.982 vs 0.826
# 0.000	0.983 vs 0.826
# 0.000	0.983 vs 0.836
# 0.000	0.984 vs 0.836
# 0.000	0.984 vs 0.841
# 0.000	0.985 vs 0.841
# 0.000	0.985 vs 0.843
# 0.000	0.986 vs 0.843
# 0.000	0.986 vs 0.846
# 0.000	0.987 vs 0.846
# 0.000	0.987 vs 0.847
# 0.000	0.988 vs 0.847
# 0.000	0.988 vs 0.850
# 0.000	0.989 vs 0.850
# 0.000	0.989 vs 0.852
# 0.000	0.990 vs 0.852
# 0.000	0.990 vs 0.854
# 0.000	0.991 vs 0.854
# 0.000	0.991 vs 0.856
# 0.000	0.993 vs 0.856
# 0.000	0.993 vs 0.860
# 0.000	0.994 vs 0.860
# 0.000	0.994 vs 0.864
# 0.000	0.994 vs 0.864
# 0.000	0.994 vs 0.864
# 0.000	0.994 vs 0.865
# 0.000	0.994 vs 0.865
# 0.000	0.994 vs 0.865
# 0.000	0.994 vs 0.866
# 0.000	0.994 vs 0.866
# 0.000	0.994 vs 0.878
# 0.000	0.994 vs 0.879
# 0.000	0.994 vs 0.896
# 0.000	0.994 vs 0.897
# 0.000	0.994 vs 0.903
# 0.000	0.994 vs 0.904
# 0.000	0.994 vs 0.905
# 0.000	0.994 vs 0.905
# 0.000	0.994 vs 0.908
# 0.000	0.994 vs 0.908
# 0.000	0.994 vs 0.909
# 0.000	0.994 vs 0.910
# 0.000	0.994 vs 0.982
# 0.000	0.995 vs 0.982
# 0.000	0.995 vs 0.988
# 0.000	0.996 vs 0.988
# 0.000	0.996 vs 0.993
# 0.000	0.997 vs 0.993
# 0.000	0.997 vs 0.995
# 0.000	0.999 vs 0.995
# 0.000	0.999 vs 1.000
# 0.000	1.000 vs 1.000
# 0.000	1.000 vs 1.000

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Get the probabilities of each class.
y_probs = QDA_classifier.predict_proba(X_test)

# Initialize lists to store TPR and FPR for each class
tpr_list = []
fpr_list = []

# Convert multi-class labels to binary labels for each class and calculate ROC curves
for pos in range(2):
    binary_labels = (y_test == pos).astype(int)
    fpr, tpr, thresholds = roc_curve(binary_labels, y_probs[:, pos], pos_label=1)
    auc = roc_auc_score(binary_labels, y_probs[:, pos])

    # Store TPR and FPR for plotting
    tpr_list.append(tpr)
    fpr_list.append(fpr)

# Plot ROC curves for all classes on the same graph
plt.figure()
lw = 2
colors = ['darkorange', 'green']
labels = ['Class 0', 'Class 1']

for i in range(len(tpr_list)):
    plt.plot(fpr_list[i], tpr_list[i], color=colors[i], lw=lw, label='ROC curve - %s' % (labels[i]))

plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (QDA)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Measuring performance on small unseen set

# %%
solution_validate = QDA_classifier.predict(future_sample_X)

# %%
score_validate = accuracy_score(future_sample_y, solution_validate)
print (score_validate)
# Out:
# 0.88

# %% [markdown]
# # MLP Classifier

# %% [markdown]
# ## Hyper parameter optimisation

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPClassifier

# Define the parameter grid to search
param_grid = {
    'hidden_layer_sizes': [(5, 2), (10, 5), (20, 10)],  # Different combinations of hidden layer sizes
    'alpha': [1e-5, 1e-4, 1e-3],  # Regularization parameter
    'solver': ['lbfgs', 'sgd', 'adam']  # Optimization algorithm
}

# Create an MLPClassifier
MLP_classifier = MLPClassifier(random_state=1)

# Instantiate GridSearchCV with the classifier, parameter grid, and cross-validation strategy
grid_search = GridSearchCV(estimator=MLP_classifier, param_grid=param_grid, cv=5, n_jobs=-1)

# Perform the grid search on the training data
grid_search.fit(X_train_resampled, y_train_resampled)

# Print the best hyperparameters and corresponding accuracy score
print("Best Hyperparameters: ", grid_search.best_params_)
print("Best Accuracy Score: ", grid_search.best_score_)
# Out:
# Best Hyperparameters:  {'alpha': 0.001, 'hidden_layer_sizes': (20, 10), 'solver': 'adam'}
# Best Accuracy Score:  0.9291146019805672

# %% [markdown]
# ## Training

# %%
from sklearn.neural_network import MLPClassifier
MLP_classifier = MLPClassifier(solver='adam', alpha= 0.001, hidden_layer_sizes=(400, 200), random_state=1)
MLP_classifier.fit(X_train_resampled, y_train_resampled)
# Out:
# MLPClassifier(alpha=0.001, hidden_layer_sizes=(400, 200), random_state=1)

# %%
# Predict the class labels of samples in the test dataset
y_pred_MLP = MLP_classifier.predict(X_test)

# %%
score_test = accuracy_score(y_test, y_pred_MLP)
print (score_test)
# Out:
# 0.9212657148945238

# %%
precision_test = precision_score(y_test, y_pred_MLP, average='macro')
print (precision_test)
# Out:
# 0.7809710762024225

# %%
recall_test = recall_score(y_test, y_pred_MLP, average='macro')
print (recall_test)
# Out:
# 0.7886355356815904

# %%
f1_test =  f1_score(y_test, y_pred_MLP, average='macro')
print(f1_test)
# Out:
# 0.7847312580212679

# %%
mat = confusion_matrix(y_test, y_pred_MLP)
class_names = ["Not Expired", "Expired"]
plt.figure(figsize=(8, 6))
sns.heatmap(mat, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix (MLP)")
plt.show()

# %%
report = classification_report(y_test, y_pred_MLP)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      8445
#            1       0.60      0.62      0.61       941
#
#     accuracy                           0.92      9386
#    macro avg       0.78      0.79      0.78      9386
# weighted avg       0.92      0.92      0.92      9386

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Get the probabilities of each class.
y_probs = MLP_classifier.predict_proba(X_test)

# The 'positive' class value is 1, so we want the probabilities of the class being 1.
# i.e., the second column of the array.
y_probs_class_1 = y_probs[:,1]

auc = roc_auc_score(y_test, y_probs_class_1)
print('The AUC is {:.3f}'.format(auc)) # uses string formatting to get 3 decimal places.

fpr, tpr, thresholds = roc_curve(y_test, y_probs_class_1, pos_label=1)

print("Threshold\tTPR vs FPR")
for f, p, t in zip(fpr, tpr, thresholds):
    print("{:.3f}\t{:.3f} vs {:.3f}".format(t, p, f))

# Here is some code to plot the ROC curve.
# Follows the example at https://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html#sphx-glr-auto-examples-model-selection-plot-roc-py

import matplotlib.pyplot as plt
plt.figure()
lw = 2 # the line width
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--') # The dashed line for random choice
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (MLP)')
plt.legend(loc="lower right")
plt.show()
# Out:
# The AUC is 0.900
# Threshold	TPR vs FPR
# 2.000	0.000 vs 0.000
# 1.000	0.002 vs 0.000
# 1.000	0.010 vs 0.000
# 1.000	0.010 vs 0.000
# 1.000	0.015 vs 0.000
# 1.000	0.015 vs 0.000
# 1.000	0.021 vs 0.000
# 1.000	0.021 vs 0.000
# 1.000	0.023 vs 0.000
# 1.000	0.023 vs 0.001
# 1.000	0.029 vs 0.001
# 1.000	0.029 vs 0.001
# 1.000	0.034 vs 0.001
# 1.000	0.034 vs 0.001
# 1.000	0.043 vs 0.001
# 1.000	0.043 vs 0.001
# 1.000	0.049 vs 0.001
# 1.000	0.049 vs 0.001
# 1.000	0.063 vs 0.001
# 1.000	0.063 vs 0.001
# 1.000	0.067 vs 0.001
# 1.000	0.067 vs 0.001
# 1.000	0.070 vs 0.001
# 1.000	0.070 vs 0.001
# 0.999	0.095 vs 0.001
# 0.999	0.095 vs 0.002
# 0.999	0.104 vs 0.002
# 0.999	0.104 vs 0.002
# 0.998	0.114 vs 0.002
# 0.998	0.114 vs 0.002
# 0.998	0.119 vs 0.002
# 0.998	0.119 vs 0.002
# 0.998	0.125 vs 0.002
# 0.998	0.125 vs 0.002
# 0.998	0.133 vs 0.002
# 0.998	0.133 vs 0.002
# 0.997	0.137 vs 0.002
# 0.997	0.137 vs 0.002
# 0.997	0.152 vs 0.002
# 0.997	0.152 vs 0.002
# 0.995	0.166 vs 0.002
# 0.995	0.166 vs 0.002
# 0.993	0.185 vs 0.002
# 0.993	0.185 vs 0.003
# 0.991	0.198 vs 0.003
# 0.991	0.198 vs 0.003
# 0.990	0.207 vs 0.003
# 0.989	0.207 vs 0.003
# 0.988	0.218 vs 0.003
# 0.987	0.218 vs 0.003
# 0.985	0.227 vs 0.003
# 0.985	0.227 vs 0.003
# 0.984	0.234 vs 0.003
# 0.984	0.234 vs 0.003
# 0.983	0.243 vs 0.003
# 0.983	0.243 vs 0.003
# 0.983	0.245 vs 0.003
# 0.982	0.245 vs 0.004
# 0.980	0.253 vs 0.004
# 0.980	0.253 vs 0.004
# 0.978	0.267 vs 0.004
# 0.978	0.267 vs 0.004
# 0.977	0.269 vs 0.004
# 0.977	0.269 vs 0.004
# 0.975	0.274 vs 0.004
# 0.975	0.274 vs 0.004
# 0.972	0.282 vs 0.004
# 0.972	0.282 vs 0.004
# 0.972	0.284 vs 0.004
# 0.972	0.284 vs 0.004
# 0.969	0.289 vs 0.004
# 0.969	0.289 vs 0.005
# 0.967	0.292 vs 0.005
# 0.966	0.292 vs 0.005
# 0.965	0.299 vs 0.005
# 0.965	0.299 vs 0.005
# 0.955	0.320 vs 0.005
# 0.955	0.320 vs 0.005
# 0.953	0.322 vs 0.005
# 0.953	0.322 vs 0.005
# 0.952	0.323 vs 0.005
# 0.952	0.323 vs 0.005
# 0.952	0.324 vs 0.005
# 0.952	0.324 vs 0.006
# 0.946	0.332 vs 0.006
# 0.946	0.332 vs 0.006
# 0.945	0.335 vs 0.006
# 0.944	0.335 vs 0.006
# 0.939	0.342 vs 0.006
# 0.938	0.342 vs 0.006
# 0.936	0.345 vs 0.006
# 0.936	0.345 vs 0.006
# 0.933	0.348 vs 0.006
# 0.931	0.348 vs 0.006
# 0.931	0.349 vs 0.006
# 0.930	0.349 vs 0.007
# 0.665	0.546 vs 0.027
# 0.663	0.546 vs 0.027
# 0.663	0.547 vs 0.027
# 0.660	0.547 vs 0.027
# 0.659	0.549 vs 0.027
# 0.653	0.549 vs 0.028
# 0.650	0.553 vs 0.028
# 0.649	0.553 vs 0.028
# 0.648	0.554 vs 0.028
# 0.646	0.554 vs 0.028
# 0.644	0.555 vs 0.028
# 0.643	0.555 vs 0.029
# 0.643	0.556 vs 0.029
# 0.642	0.556 vs 0.029
# 0.641	0.557 vs 0.029
# 0.641	0.557 vs 0.029
# 0.640	0.558 vs 0.029
# 0.639	0.558 vs 0.029
# 0.635	0.561 vs 0.029
# 0.635	0.561 vs 0.029
# 0.634	0.562 vs 0.029
# 0.634	0.562 vs 0.029
# 0.632	0.566 vs 0.029
# 0.631	0.566 vs 0.030
# 0.629	0.570 vs 0.030
# 0.622	0.570 vs 0.031
# 0.622	0.571 vs 0.031
# 0.621	0.571 vs 0.031
# 0.620	0.572 vs 0.031
# 0.617	0.572 vs 0.031
# 0.617	0.573 vs 0.031
# 0.614	0.573 vs 0.032
# 0.613	0.574 vs 0.032
# 0.611	0.574 vs 0.032
# 0.608	0.576 vs 0.032
# 0.598	0.576 vs 0.033
# 0.597	0.578 vs 0.033
# 0.595	0.578 vs 0.034
# 0.595	0.580 vs 0.034
# 0.593	0.580 vs 0.034
# 0.593	0.581 vs 0.034
# 0.591	0.581 vs 0.035
# 0.591	0.582 vs 0.035
# 0.588	0.582 vs 0.035
# 0.585	0.586 vs 0.035
# 0.583	0.586 vs 0.036
# 0.582	0.587 vs 0.036
# 0.580	0.587 vs 0.036
# 0.579	0.588 vs 0.036
# 0.565	0.588 vs 0.037
# 0.563	0.589 vs 0.037
# 0.560	0.589 vs 0.038
# 0.558	0.590 vs 0.038
# 0.557	0.590 vs 0.038
# 0.557	0.591 vs 0.038
# 0.556	0.591 vs 0.038
# 0.556	0.592 vs 0.038
# 0.555	0.592 vs 0.038
# 0.555	0.593 vs 0.038
# 0.554	0.593 vs 0.038
# 0.554	0.594 vs 0.038
# 0.554	0.594 vs 0.038
# 0.553	0.595 vs 0.038
# 0.551	0.595 vs 0.039
# 0.550	0.596 vs 0.039
# 0.549	0.596 vs 0.039
# 0.548	0.597 vs 0.039
# 0.547	0.597 vs 0.039
# 0.546	0.598 vs 0.039
# 0.545	0.598 vs 0.040
# 0.545	0.600 vs 0.040
# 0.543	0.600 vs 0.040
# 0.541	0.601 vs 0.040
# 0.538	0.601 vs 0.040
# 0.537	0.604 vs 0.040
# 0.536	0.604 vs 0.041
# 0.535	0.605 vs 0.041
# 0.532	0.605 vs 0.041
# 0.532	0.607 vs 0.041
# 0.531	0.607 vs 0.042
# 0.531	0.608 vs 0.042
# 0.529	0.608 vs 0.042
# 0.529	0.609 vs 0.042
# 0.529	0.609 vs 0.042
# 0.528	0.610 vs 0.042
# 0.527	0.610 vs 0.043
# 0.526	0.611 vs 0.043
# 0.526	0.611 vs 0.043
# 0.524	0.612 vs 0.043
# 0.522	0.612 vs 0.044
# 0.521	0.614 vs 0.044
# 0.520	0.614 vs 0.044
# 0.518	0.616 vs 0.044
# 0.513	0.616 vs 0.044
# 0.511	0.620 vs 0.044
# 0.510	0.620 vs 0.044
# 0.510	0.621 vs 0.044
# 0.509	0.621 vs 0.045
# 0.509	0.622 vs 0.045
# 0.502	0.622 vs 0.045
# 0.502	0.623 vs 0.045
# 0.500	0.623 vs 0.046
# 0.499	0.628 vs 0.046
# 0.495	0.628 vs 0.046
# 0.495	0.630 vs 0.046
# 0.490	0.630 vs 0.046
# 0.490	0.631 vs 0.046
# 0.489	0.631 vs 0.047
# 0.488	0.632 vs 0.047
# 0.480	0.632 vs 0.048
# 0.480	0.633 vs 0.048
# 0.477	0.633 vs 0.049
# 0.477	0.634 vs 0.049
# 0.475	0.634 vs 0.049
# 0.475	0.635 vs 0.049
# 0.472	0.635 vs 0.050
# 0.471	0.637 vs 0.050
# 0.469	0.637 vs 0.050
# 0.467	0.638 vs 0.050
# 0.465	0.638 vs 0.051
# 0.463	0.639 vs 0.051
# 0.462	0.639 vs 0.051
# 0.461	0.640 vs 0.051
# 0.456	0.640 vs 0.052
# 0.452	0.643 vs 0.052
# 0.451	0.643 vs 0.052
# 0.451	0.644 vs 0.052
# 0.451	0.644 vs 0.052
# 0.451	0.645 vs 0.052
# 0.449	0.645 vs 0.052
# 0.448	0.646 vs 0.052
# 0.445	0.646 vs 0.053
# 0.444	0.647 vs 0.053
# 0.444	0.647 vs 0.053
# 0.444	0.648 vs 0.053
# 0.442	0.648 vs 0.054
# 0.441	0.650 vs 0.054
# 0.438	0.650 vs 0.054
# 0.437	0.654 vs 0.054
# 0.436	0.654 vs 0.054
# 0.436	0.655 vs 0.054
# 0.436	0.655 vs 0.054
# 0.436	0.656 vs 0.054
# 0.434	0.656 vs 0.055
# 0.434	0.657 vs 0.055
# 0.430	0.657 vs 0.056
# 0.430	0.658 vs 0.056
# 0.428	0.658 vs 0.056
# 0.428	0.659 vs 0.056
# 0.422	0.659 vs 0.058
# 0.421	0.660 vs 0.058
# 0.421	0.660 vs 0.058
# 0.420	0.662 vs 0.058
# 0.418	0.662 vs 0.059
# 0.417	0.663 vs 0.059
# 0.415	0.663 vs 0.059
# 0.414	0.665 vs 0.059
# 0.412	0.665 vs 0.060
# 0.412	0.666 vs 0.060
# 0.408	0.666 vs 0.060
# 0.407	0.668 vs 0.060
# 0.407	0.668 vs 0.061
# 0.407	0.670 vs 0.061
# 0.403	0.670 vs 0.062
# 0.403	0.671 vs 0.062
# 0.401	0.671 vs 0.062
# 0.400	0.672 vs 0.062
# 0.399	0.672 vs 0.062
# 0.399	0.673 vs 0.062
# 0.395	0.673 vs 0.063
# 0.395	0.674 vs 0.063
# 0.391	0.674 vs 0.063
# 0.391	0.675 vs 0.063
# 0.387	0.675 vs 0.064
# 0.386	0.676 vs 0.064
# 0.386	0.676 vs 0.064
# 0.385	0.678 vs 0.064
# 0.383	0.678 vs 0.065
# 0.383	0.679 vs 0.065
# 0.380	0.679 vs 0.065
# 0.264	0.738 vs 0.096
# 0.263	0.738 vs 0.097
# 0.262	0.739 vs 0.097
# 0.258	0.739 vs 0.099
# 0.258	0.740 vs 0.099
# 0.256	0.740 vs 0.099
# 0.256	0.741 vs 0.099
# 0.251	0.741 vs 0.101
# 0.250	0.742 vs 0.101
# 0.245	0.742 vs 0.103
# 0.244	0.743 vs 0.103
# 0.242	0.743 vs 0.104
# 0.242	0.744 vs 0.104
# 0.240	0.744 vs 0.104
# 0.240	0.745 vs 0.104
# 0.239	0.745 vs 0.105
# 0.239	0.747 vs 0.105
# 0.237	0.747 vs 0.106
# 0.237	0.748 vs 0.106
# 0.229	0.748 vs 0.108
# 0.229	0.749 vs 0.108
# 0.221	0.749 vs 0.110
# 0.221	0.750 vs 0.110
# 0.220	0.750 vs 0.111
# 0.220	0.751 vs 0.111
# 0.219	0.751 vs 0.111
# 0.218	0.752 vs 0.111
# 0.213	0.752 vs 0.113
# 0.213	0.753 vs 0.113
# 0.210	0.753 vs 0.115
# 0.210	0.755 vs 0.115
# 0.205	0.755 vs 0.117
# 0.205	0.756 vs 0.117
# 0.204	0.756 vs 0.117
# 0.204	0.757 vs 0.117
# 0.203	0.757 vs 0.118
# 0.203	0.758 vs 0.118
# 0.202	0.758 vs 0.118
# 0.202	0.759 vs 0.118
# 0.201	0.759 vs 0.119
# 0.201	0.760 vs 0.119
# 0.200	0.760 vs 0.119
# 0.200	0.761 vs 0.119
# 0.199	0.761 vs 0.120
# 0.199	0.762 vs 0.120
# 0.195	0.762 vs 0.122
# 0.194	0.763 vs 0.122
# 0.194	0.763 vs 0.122
# 0.194	0.764 vs 0.122
# 0.190	0.764 vs 0.124
# 0.190	0.765 vs 0.124
# 0.189	0.765 vs 0.124
# 0.189	0.766 vs 0.124
# 0.189	0.766 vs 0.125
# 0.188	0.767 vs 0.125
# 0.186	0.767 vs 0.126
# 0.186	0.769 vs 0.126
# 0.184	0.769 vs 0.126
# 0.184	0.770 vs 0.126
# 0.184	0.770 vs 0.127
# 0.184	0.772 vs 0.127
# 0.180	0.772 vs 0.129
# 0.180	0.773 vs 0.129
# 0.179	0.773 vs 0.129
# 0.179	0.774 vs 0.129
# 0.172	0.774 vs 0.132
# 0.172	0.775 vs 0.132
# 0.172	0.775 vs 0.133
# 0.171	0.776 vs 0.133
# 0.170	0.776 vs 0.133
# 0.169	0.778 vs 0.133
# 0.169	0.778 vs 0.134
# 0.169	0.779 vs 0.134
# 0.167	0.779 vs 0.135
# 0.166	0.780 vs 0.135
# 0.163	0.780 vs 0.137
# 0.163	0.783 vs 0.137
# 0.162	0.783 vs 0.138
# 0.161	0.784 vs 0.138
# 0.157	0.784 vs 0.141
# 0.157	0.785 vs 0.141
# 0.157	0.785 vs 0.141
# 0.157	0.786 vs 0.141
# 0.157	0.786 vs 0.141
# 0.157	0.787 vs 0.141
# 0.156	0.787 vs 0.142
# 0.156	0.789 vs 0.142
# 0.155	0.789 vs 0.142
# 0.155	0.790 vs 0.142
# 0.153	0.790 vs 0.143
# 0.078	0.837 vs 0.204
# 0.078	0.838 vs 0.204
# 0.072	0.838 vs 0.211
# 0.072	0.840 vs 0.211
# 0.070	0.840 vs 0.214
# 0.070	0.841 vs 0.214
# 0.066	0.841 vs 0.220
# 0.066	0.842 vs 0.220
# 0.065	0.842 vs 0.222
# 0.065	0.843 vs 0.222
# 0.064	0.843 vs 0.222
# 0.064	0.844 vs 0.222
# 0.064	0.844 vs 0.222
# 0.064	0.845 vs 0.222
# 0.061	0.845 vs 0.227
# 0.061	0.846 vs 0.227
# 0.061	0.846 vs 0.227
# 0.061	0.847 vs 0.227
# 0.060	0.847 vs 0.227
# 0.060	0.848 vs 0.227
# 0.060	0.848 vs 0.228
# 0.060	0.849 vs 0.228
# 0.060	0.849 vs 0.228
# 0.060	0.850 vs 0.228
# 0.060	0.850 vs 0.229
# 0.060	0.851 vs 0.229
# 0.059	0.851 vs 0.229
# 0.059	0.852 vs 0.229
# 0.057	0.852 vs 0.232
# 0.057	0.853 vs 0.232
# 0.056	0.853 vs 0.234
# 0.056	0.854 vs 0.234
# 0.056	0.854 vs 0.235
# 0.056	0.855 vs 0.235
# 0.055	0.855 vs 0.236
# 0.055	0.857 vs 0.236
# 0.055	0.857 vs 0.237
# 0.055	0.858 vs 0.237
# 0.052	0.858 vs 0.241
# 0.052	0.859 vs 0.241
# 0.052	0.859 vs 0.242
# 0.052	0.860 vs 0.242
# 0.052	0.860 vs 0.242
# 0.052	0.861 vs 0.242
# 0.051	0.861 vs 0.244
# 0.051	0.862 vs 0.244
# 0.050	0.862 vs 0.244
# 0.050	0.863 vs 0.244
# 0.048	0.863 vs 0.249
# 0.048	0.864 vs 0.249
# 0.048	0.864 vs 0.249
# 0.048	0.865 vs 0.249
# 0.048	0.865 vs 0.250
# 0.048	0.866 vs 0.250
# 0.048	0.866 vs 0.250
# 0.047	0.867 vs 0.250
# 0.047	0.867 vs 0.250
# 0.047	0.868 vs 0.250
# 0.047	0.868 vs 0.251
# 0.047	0.869 vs 0.251
# 0.045	0.869 vs 0.255
# 0.045	0.870 vs 0.255
# 0.044	0.870 vs 0.258
# 0.044	0.871 vs 0.258
# 0.041	0.871 vs 0.265
# 0.041	0.872 vs 0.265
# 0.040	0.872 vs 0.267
# 0.039	0.874 vs 0.267
# 0.039	0.874 vs 0.268
# 0.039	0.875 vs 0.268
# 0.038	0.875 vs 0.269
# 0.038	0.876 vs 0.269
# 0.036	0.876 vs 0.275
# 0.036	0.877 vs 0.275
# 0.036	0.877 vs 0.275
# 0.035	0.878 vs 0.275
# 0.035	0.878 vs 0.276
# 0.035	0.879 vs 0.276
# 0.035	0.879 vs 0.276
# 0.035	0.880 vs 0.276
# 0.032	0.880 vs 0.281
# 0.032	0.881 vs 0.281
# 0.032	0.881 vs 0.282
# 0.032	0.882 vs 0.282
# 0.031	0.882 vs 0.284
# 0.031	0.883 vs 0.284
# 0.028	0.883 vs 0.293
# 0.028	0.884 vs 0.293
# 0.028	0.884 vs 0.293
# 0.028	0.885 vs 0.293
# 0.028	0.885 vs 0.295
# 0.028	0.886 vs 0.295
# 0.027	0.886 vs 0.296
# 0.027	0.887 vs 0.296
# 0.026	0.887 vs 0.300
# 0.026	0.888 vs 0.300
# 0.024	0.888 vs 0.305
# 0.024	0.889 vs 0.305
# 0.023	0.889 vs 0.309
# 0.023	0.891 vs 0.309
# 0.023	0.891 vs 0.309
# 0.023	0.892 vs 0.309
# 0.023	0.892 vs 0.311
# 0.023	0.893 vs 0.311
# 0.022	0.893 vs 0.312
# 0.022	0.894 vs 0.312
# 0.021	0.894 vs 0.316
# 0.021	0.895 vs 0.316
# 0.021	0.895 vs 0.317
# 0.021	0.896 vs 0.317
# 0.021	0.896 vs 0.318
# 0.021	0.897 vs 0.318
# 0.019	0.897 vs 0.328
# 0.019	0.899 vs 0.328
# 0.018	0.899 vs 0.333
# 0.018	0.900 vs 0.333
# 0.017	0.900 vs 0.335
# 0.017	0.902 vs 0.335
# 0.017	0.902 vs 0.335
# 0.017	0.903 vs 0.335
# 0.017	0.903 vs 0.338
# 0.016	0.905 vs 0.338
# 0.016	0.905 vs 0.342
# 0.016	0.906 vs 0.342
# 0.015	0.906 vs 0.345
# 0.015	0.908 vs 0.345
# 0.015	0.908 vs 0.349
# 0.015	0.909 vs 0.349
# 0.013	0.909 vs 0.359
# 0.013	0.910 vs 0.359
# 0.013	0.910 vs 0.359
# 0.013	0.911 vs 0.359
# 0.012	0.911 vs 0.362
# 0.012	0.912 vs 0.362
# 0.012	0.912 vs 0.363
# 0.012	0.913 vs 0.363
# 0.012	0.913 vs 0.364
# 0.012	0.914 vs 0.364
# 0.012	0.914 vs 0.366
# 0.012	0.915 vs 0.366
# 0.011	0.915 vs 0.368
# 0.011	0.916 vs 0.368
# 0.011	0.916 vs 0.373
# 0.011	0.918 vs 0.373
# 0.010	0.918 vs 0.375
# 0.010	0.919 vs 0.375
# 0.010	0.919 vs 0.379
# 0.010	0.920 vs 0.379
# 0.010	0.920 vs 0.382
# 0.010	0.921 vs 0.382
# 0.009	0.921 vs 0.384
# 0.009	0.922 vs 0.384
# 0.008	0.922 vs 0.393
# 0.008	0.923 vs 0.393
# 0.008	0.923 vs 0.394
# 0.008	0.925 vs 0.394
# 0.008	0.925 vs 0.395
# 0.008	0.926 vs 0.395
# 0.007	0.926 vs 0.401
# 0.007	0.927 vs 0.401
# 0.006	0.927 vs 0.416
# 0.006	0.928 vs 0.416
# 0.006	0.928 vs 0.422
# 0.006	0.929 vs 0.422
# 0.006	0.929 vs 0.422
# 0.006	0.930 vs 0.422
# 0.006	0.930 vs 0.425
# 0.005	0.931 vs 0.425
# 0.004	0.931 vs 0.439
# 0.004	0.932 vs 0.439
# 0.004	0.932 vs 0.450
# 0.004	0.933 vs 0.450
# 0.003	0.933 vs 0.457
# 0.003	0.934 vs 0.457
# 0.003	0.934 vs 0.469
# 0.003	0.935 vs 0.469
# 0.003	0.935 vs 0.477
# 0.003	0.936 vs 0.477
# 0.003	0.936 vs 0.478
# 0.003	0.937 vs 0.478
# 0.002	0.937 vs 0.480
# 0.002	0.938 vs 0.480
# 0.002	0.938 vs 0.485
# 0.002	0.939 vs 0.485
# 0.002	0.939 vs 0.486
# 0.002	0.940 vs 0.486
# 0.002	0.940 vs 0.486
# 0.002	0.942 vs 0.486
# 0.002	0.942 vs 0.494
# 0.002	0.943 vs 0.494
# 0.002	0.943 vs 0.497
# 0.002	0.944 vs 0.497
# 0.002	0.944 vs 0.501
# 0.002	0.945 vs 0.501
# 0.002	0.945 vs 0.501
# 0.002	0.946 vs 0.501
# 0.002	0.946 vs 0.503
# 0.002	0.947 vs 0.503
# 0.002	0.947 vs 0.504
# 0.002	0.948 vs 0.504
# 0.001	0.948 vs 0.512
# 0.001	0.949 vs 0.512
# 0.001	0.949 vs 0.513
# 0.001	0.950 vs 0.513
# 0.001	0.950 vs 0.513
# 0.001	0.951 vs 0.513
# 0.001	0.951 vs 0.513
# 0.001	0.952 vs 0.513
# 0.001	0.952 vs 0.515
# 0.001	0.953 vs 0.515
# 0.001	0.953 vs 0.519
# 0.001	0.954 vs 0.519
# 0.001	0.954 vs 0.526
# 0.001	0.955 vs 0.526
# 0.001	0.955 vs 0.529
# 0.001	0.956 vs 0.529
# 0.001	0.956 vs 0.533
# 0.001	0.957 vs 0.533
# 0.001	0.957 vs 0.550
# 0.001	0.959 vs 0.550
# 0.001	0.959 vs 0.555
# 0.001	0.960 vs 0.555
# 0.001	0.960 vs 0.557
# 0.001	0.961 vs 0.557
# 0.001	0.961 vs 0.558
# 0.001	0.962 vs 0.558
# 0.001	0.962 vs 0.559
# 0.001	0.963 vs 0.559
# 0.000	0.963 vs 0.568
# 0.000	0.964 vs 0.568
# 0.000	0.964 vs 0.571
# 0.000	0.965 vs 0.571
# 0.000	0.965 vs 0.589
# 0.000	0.966 vs 0.589
# 0.000	0.966 vs 0.601
# 0.000	0.967 vs 0.601
# 0.000	0.967 vs 0.616
# 0.000	0.968 vs 0.616
# 0.000	0.968 vs 0.618
# 0.000	0.969 vs 0.618
# 0.000	0.969 vs 0.635
# 0.000	0.971 vs 0.635
# 0.000	0.971 vs 0.638
# 0.000	0.972 vs 0.638
# 0.000	0.972 vs 0.640
# 0.000	0.973 vs 0.640
# 0.000	0.973 vs 0.644
# 0.000	0.974 vs 0.644
# 0.000	0.974 vs 0.661
# 0.000	0.976 vs 0.661
# 0.000	0.976 vs 0.677
# 0.000	0.977 vs 0.677
# 0.000	0.977 vs 0.685
# 0.000	0.978 vs 0.685
# 0.000	0.978 vs 0.686
# 0.000	0.979 vs 0.686
# 0.000	0.979 vs 0.718
# 0.000	0.980 vs 0.718
# 0.000	0.980 vs 0.729
# 0.000	0.981 vs 0.729
# 0.000	0.981 vs 0.734
# 0.000	0.982 vs 0.734
# 0.000	0.982 vs 0.742
# 0.000	0.983 vs 0.742
# 0.000	0.983 vs 0.751
# 0.000	0.984 vs 0.751
# 0.000	0.984 vs 0.754
# 0.000	0.985 vs 0.754
# 0.000	0.985 vs 0.763
# 0.000	0.986 vs 0.763
# 0.000	0.986 vs 0.764
# 0.000	0.987 vs 0.764
# 0.000	0.987 vs 0.768
# 0.000	0.988 vs 0.768
# 0.000	0.988 vs 0.770
# 0.000	0.989 vs 0.770
# 0.000	0.989 vs 0.774
# 0.000	0.990 vs 0.774
# 0.000	0.990 vs 0.789
# 0.000	0.991 vs 0.789
# 0.000	0.991 vs 0.792
# 0.000	0.994 vs 0.792
# 0.000	0.994 vs 0.797
# 0.000	0.995 vs 0.797
# 0.000	0.995 vs 0.818
# 0.000	0.996 vs 0.818
# 0.000	0.996 vs 0.839
# 0.000	0.997 vs 0.839
# 0.000	0.997 vs 0.860
# 0.000	0.998 vs 0.860
# 0.000	0.998 vs 0.863
# 0.000	0.999 vs 0.863
# 0.000	0.999 vs 0.935
# 0.000	0.999 vs 0.935
# 0.000	0.999 vs 1.000
# 0.000	1.000 vs 1.000
# 0.000	1.000 vs 1.000

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Get the probabilities of each class.
y_probs = MLP_classifier.predict_proba(X_test)

# Initialize lists to store TPR and FPR for each class
tpr_list = []
fpr_list = []

# Convert multi-class labels to binary labels for each class and calculate ROC curves
for pos in range(2):
    binary_labels = (y_test == pos).astype(int)
    fpr, tpr, thresholds = roc_curve(binary_labels, y_probs[:, pos], pos_label=1)
    auc = roc_auc_score(binary_labels, y_probs[:, pos])

    # Store TPR and FPR for plotting
    tpr_list.append(tpr)
    fpr_list.append(fpr)

# Plot ROC curves for all classes on the same graph
plt.figure()
lw = 2
colors = ['darkorange', 'green']
labels = ['Class 0', 'Class 1']

for i in range(len(tpr_list)):
    plt.plot(fpr_list[i], tpr_list[i], color=colors[i], lw=lw, label='ROC curve - %s' % (labels[i]))

plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (MLP)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Measuring performance on small unseen set

# %%
solution_validate = MLP_classifier.predict(future_sample_X)

# %%
score_validate = accuracy_score(future_sample_y, solution_validate)
print (score_validate)
# Out:
# 0.92

# %% [markdown]
# # Run Classifiers

# %%
# # DT
# DT_predictions = DT_classifier.predict(testing_data_set)
# DT_predictions_df = pd.DataFrame({'Predicted-ExpiredHospital': DT_predictions})

# # kNN
# KNN_predictions = KNN_classifier.predict(testing_data_set)
# KNN_predictions_df = pd.DataFrame({'Predicted-ExpiredHospital': KNN_predictions})

# RF
RF_predictions = RF_classifier.predict(testing_data_set_fs)
RF_predictions_df = pd.DataFrame({'Predicted-ExpiredHospital': RF_predictions})

# # # SVM
# SVM_predictions = SVM_classifier.predict(testing_data_set)
# SVM_predictions_df = pd.DataFrame({'Predicted-ExpiredHospital': SVM_predictions})

# %%
# FNN
FNN_predictions = loaded_model.predict(testing_data_set)
FNN_predictions_flat = np.array(FNN_predictions).flatten()

# Apply threshold to convert probabilities to binary predictions
threshold = 0.5
binary_predictions = (FNN_predictions_flat > threshold).astype(int)

# Create a dataframe for binary predictions
FNN_predictions_df = pd.DataFrame({'Predicted-ExpiredHospital': binary_predictions})
# Out:
# 369/369 [==============================] - 7s 19ms/step

# %%
DT_predictions_df
# Out:
#        Predicted-ExpiredHospital
# 0                              0
# 1                              1
# 2                              0
# 3                              0
# 4                              0
# ...                          ...
# 11791                          0
# 11792                          1
# 11793                          0
# 11794                          0
# 11795                          0
#
# [11796 rows x 1 columns]

# %%
DT_predictions_df['row ID'] = ['Row' + str(i) for i in range(len(DT_predictions_df))]
DT_predictions_df = DT_predictions_df[['row ID', 'Predicted-ExpiredHospital']]
DT_predictions_df
# Out:
#          row ID  Predicted-ExpiredHospital
# 0          Row0                          0
# 1          Row1                          1
# 2          Row2                          0
# 3          Row3                          0
# 4          Row4                          0
# ...         ...                        ...
# 11791  Row11791                          0
# 11792  Row11792                          1
# 11793  Row11793                          0
# 11794  Row11794                          0
# 11795  Row11795                          0
#
# [11796 rows x 2 columns]

# %%
KNN_predictions_df['row ID'] = ['Row' + str(i) for i in range(len(KNN_predictions_df))]
KNN_predictions_df = KNN_predictions_df[['row ID', 'Predicted-ExpiredHospital']]
KNN_predictions_df
# Out:
#          row ID  Predicted-ExpiredHospital
# 0          Row0                          0
# 1          Row1                          0
# 2          Row2                          0
# 3          Row3                          0
# 4          Row4                          0
# ...         ...                        ...
# 11791  Row11791                          0
# 11792  Row11792                          0
# 11793  Row11793                          0
# 11794  Row11794                          0
# 11795  Row11795                          0
#
# [11796 rows x 2 columns]

# %%
RF_predictions_df['row ID'] = ['Row' + str(i) for i in range(len(RF_predictions_df))]
RF_predictions_df = RF_predictions_df[['row ID', 'Predicted-ExpiredHospital']]
RF_predictions_df
# Out:
#          row ID  Predicted-ExpiredHospital
# 0          Row0                          0
# 1          Row1                          1
# 2          Row2                          0
# 3          Row3                          0
# 4          Row4                          0
# ...         ...                        ...
# 11791  Row11791                          0
# 11792  Row11792                          1
# 11793  Row11793                          0
# 11794  Row11794                          1
# 11795  Row11795                          0
#
# [11796 rows x 2 columns]

# %%
SVM_predictions_df['row ID'] = ['Row' + str(i) for i in range(len(SVM_predictions_df))]
SVM_predictions_df = SVM_predictions_df[['row ID', 'Predicted-ExpiredHospital']]
SVM_predictions_df
# Out:
#          row ID  Predicted-ExpiredHospital
# 0          Row0                          0
# 1          Row1                          1
# 2          Row2                          0
# 3          Row3                          0
# 4          Row4                          0
# ...         ...                        ...
# 11791  Row11791                          0
# 11792  Row11792                          1
# 11793  Row11793                          0
# 11794  Row11794                          1
# 11795  Row11795                          0
#
# [11796 rows x 2 columns]

# %%
FNN_predictions_df['row ID'] = ['Row' + str(i) for i in range(len(FNN_predictions_df))]
FNN_predictions_df = FNN_predictions_df[['row ID', 'Predicted-ExpiredHospital']]
FNN_predictions_df
# Out:
#          row ID  Predicted-ExpiredHospital
# 0          Row0                          0
# 1          Row1                          0
# 2          Row2                          0
# 3          Row3                          0
# 4          Row4                          0
# ...         ...                        ...
# 11791  Row11791                          0
# 11792  Row11792                          0
# 11793  Row11793                          0
# 11794  Row11794                          0
# 11795  Row11795                          0
#
# [11796 rows x 2 columns]

# %% [markdown]
# ## Turn Prediction Dataframes into CSV files

# %%
# DT_predictions_df.to_csv('DT.csv', index=False)
# KNN_predictions_df.to_csv('KNN.csv', index=False)
RF_predictions_df.to_csv('RF.csv', index=False)
# SVM_predictions_df.to_csv('SVM.csv', index=False)
# FNN_predictions_df.to_csv('FNN.csv', index=False)
